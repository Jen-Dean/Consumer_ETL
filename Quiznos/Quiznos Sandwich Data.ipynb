# %%
#import dependencies

import pandas as pd
import os

# %%
#import CSVs from 'Quiznos CSV' folder

quiznos_1 = pd.read_csv("Quiznos CSVs/Quiznos_1.csv")
quiznos_2 = pd.read_csv("Quiznos CSVs/Quiznos_2.csv")
quiznos_3 = pd.read_csv("Quiznos CSVs/Quiznos_3.csv")

#quiznos_1 has 21 rows

#quiznos_2 has 29 rows

#quiznos_3 has 79 rows

# %%
#merging all dataframes using .append,
quiznos_df_starter = quiznos_1.append(quiznos_2)
quiznos_df_all = quiznos_df_starter.append(quiznos_3)

quiznos_df_all
# Out:
#     Unnamed: 0                                   Name of Sandwich  \
# 0       4" Sub  Classic Italian - with capicola, salami, ham, ...
# 1       8" Sub  Classic Italian - with capicola, salami, ham, ...
# 2      12" Sub  Classic Italian - with capicola, salami, ham, ...
# 3       Sammie  Classic Italian - with capicola, salami, ham, ...
# 4       4" Sub  Turkey Ranch & Swiss - with lettuce, tomatoes,...
# ..         ...                                                ...
# 74      4" Sub  Lobster & Seafood Salad - with lobster & seafo...
# 75      8" Sub  Lobster & Seafood Salad - with lobster & seafo...
# 76     12" Sub  Lobster & Seafood Salad - with lobster & seafo...
# 77      Sammie  Lobster & Seafood Salad - with lobster & seafo...
# 78  Half Salad  Lobster & Seafood Salad - with lobster & seafo...
#
#     Calories (kcal)  Fat Calories (kcal)  Fat (g)  Saturated Fat (g)  \
# 0             450.0                210.0     23.0                8.0
# 1             890.0                430.0     48.0               15.0
# 2            1260.0                560.0     63.0               22.0
# 3             330.0                240.0     26.0                9.0
# 4             340.0                110.0     12.0                4.5
# ..              ...                  ...      ...                ...
# 74            300.0                100.0     11.0                5.0
# 75            610.0                200.0     22.0               10.0
# 76            910.0                300.0     33.0               15.0
# 77            300.0                120.0     13.0                5.0
# 78            300.0                220.0     24.0                4.0
#
#     Total Trans Fat (g)  Cholesterol (mg)  Sodium (mg)  Carbs (g)  \
# 0                   0.0              55.0       1350.0       40.0
# 1                   1.0              90.0       2540.0       79.0
# 2                   1.0             160.0       3760.0      115.0
# 3                   0.0              65.0       1240.0       37.0
# 4                   0.0              40.0        980.0       37.0
# ..                  ...               ...          ...        ...
# 74                  0.0              35.0        850.0       40.0
# 75                  0.5              70.0       1690.0       80.0
# 76                  1.0             100.0       2540.0      120.0
# 77                  0.0              35.0        810.0       34.0
# 78                  0.0              40.0        980.0       12.0
#
#     Dietary Fiber (g)  Sugars (g)  Protein (g)
# 0                 3.0         5.0         21.0
# 1                 5.0        10.0         38.0
# 2                 8.0        13.0         61.0
# 3                 1.0         3.0         18.0
# 4                 2.0         4.0         20.0
# ..                ...         ...          ...
# 74                2.0         3.0         12.0
# 75                5.0         6.0         24.0
# 76                7.0        10.0         35.0
# 77                4.0         3.0         11.0
# 78                3.0         4.0          8.0
#
# [131 rows x 13 columns]

# %%
#find the names of the columns
quiznos_df_all.columns
# Out:
# Index(['Unnamed: 0', 'Name of Sandwich', 'Calories (kcal)',
#        'Fat Calories (kcal)', 'Fat (g)', 'Saturated Fat (g)',
#        'Total Trans Fat (g)', 'Cholesterol (mg)', 'Sodium (mg)', 'Carbs (g)',
#        'Dietary Fiber (g)', 'Sugars (g)', 'Protein (g)'],
#       dtype='object')

# %%
#renaming the columns to match the final postgres table
quiznos_df_renamed = quiznos_df_all.rename(columns = {'Unnamed: 0': 'sandwich_length', 
                                 'Name of Sandwich': 'sandwich_name', 
                                 'Calories (kcal)': 'calories',
                                 'Fat Calories (kcal)' : 'calories_from_fat', 
                                 'Fat (g)': 'total_fat', 
                                 'Saturated Fat (g)' : 'saturated_fat',
                                 'Total Trans Fat (g)' : 'trans_fat', 
                                 'Cholesterol (mg)' : 'cholesterol', 
                                 'Sodium (mg)': 'sodium', 
                                 'Carbs (g)': 'total_carbohydrates', 
                                 'Dietary Fiber (g)' : 'dietary_fiber', 
                                 'Sugars (g)' : 'sugars', 
                                 'Protein (g)' : 'protein'})

quiznos_df_renamed.head()
# Out:
#   sandwich_length                                      sandwich_name  \
# 0          4" Sub  Classic Italian - with capicola, salami, ham, ...
# 1          8" Sub  Classic Italian - with capicola, salami, ham, ...
# 2         12" Sub  Classic Italian - with capicola, salami, ham, ...
# 3          Sammie  Classic Italian - with capicola, salami, ham, ...
# 4          4" Sub  Turkey Ranch & Swiss - with lettuce, tomatoes,...
#
#    calories  calories_from_fat  total_fat  saturated_fat  trans_fat  \
# 0     450.0              210.0       23.0            8.0        0.0
# 1     890.0              430.0       48.0           15.0        1.0
# 2    1260.0              560.0       63.0           22.0        1.0
# 3     330.0              240.0       26.0            9.0        0.0
# 4     340.0              110.0       12.0            4.5        0.0
#
#    cholesterol  sodium  total_carbohydrates  dietary_fiber  sugars  protein
# 0         55.0  1350.0                 40.0            3.0     5.0     21.0
# 1         90.0  2540.0                 79.0            5.0    10.0     38.0
# 2        160.0  3760.0                115.0            8.0    13.0     61.0
# 3         65.0  1240.0                 37.0            1.0     3.0     18.0
# 4         40.0   980.0                 37.0            2.0     4.0     20.0

# %%
#adding additional columns to df
quiznos_df_renamed['restaurant_name'] = ""
quiznos_df_renamed['sandwich_description'] = ""
quiznos_df_renamed['bread_type'] = ""

quiznos_df_renamed.head()
# Out:
#   sandwich_length                                      sandwich_name  \
# 0          4" Sub  Classic Italian - with capicola, salami, ham, ...
# 1          8" Sub  Classic Italian - with capicola, salami, ham, ...
# 2         12" Sub  Classic Italian - with capicola, salami, ham, ...
# 3          Sammie  Classic Italian - with capicola, salami, ham, ...
# 4          4" Sub  Turkey Ranch & Swiss - with lettuce, tomatoes,...
#
#    calories  calories_from_fat  total_fat  saturated_fat  trans_fat  \
# 0     450.0              210.0       23.0            8.0        0.0
# 1     890.0              430.0       48.0           15.0        1.0
# 2    1260.0              560.0       63.0           22.0        1.0
# 3     330.0              240.0       26.0            9.0        0.0
# 4     340.0              110.0       12.0            4.5        0.0
#
#    cholesterol  sodium  total_carbohydrates  dietary_fiber  sugars  protein  \
# 0         55.0  1350.0                 40.0            3.0     5.0     21.0
# 1         90.0  2540.0                 79.0            5.0    10.0     38.0
# 2        160.0  3760.0                115.0            8.0    13.0     61.0
# 3         65.0  1240.0                 37.0            1.0     3.0     18.0
# 4         40.0   980.0                 37.0            2.0     4.0     20.0
#
#   restaurant_name sandwich_description bread_type
# 0
# 1
# 2
# 3
# 4

# %%
#finding column names and reordering
quiznos_df_reordered = quiznos_df_renamed[['restaurant_name', 'sandwich_name', 'sandwich_description', 
                                          'sandwich_length', 'bread_type', 'calories',
                                          'calories_from_fat','total_fat', 'saturated_fat',
                                          'trans_fat', 'cholesterol', 'sodium', 'total_carbohydrates',
                                          'dietary_fiber', 'sugars', 'protein']]
quiznos_df_reordered.head()
# Out:
#   restaurant_name                                      sandwich_name  \
# 0                  Classic Italian - with capicola, salami, ham, ...
# 1                  Classic Italian - with capicola, salami, ham, ...
# 2                  Classic Italian - with capicola, salami, ham, ...
# 3                  Classic Italian - with capicola, salami, ham, ...
# 4                  Turkey Ranch & Swiss - with lettuce, tomatoes,...
#
#   sandwich_description sandwich_length bread_type  calories  \
# 0                               4" Sub                450.0
# 1                               8" Sub                890.0
# 2                              12" Sub               1260.0
# 3                               Sammie                330.0
# 4                               4" Sub                340.0
#
#    calories_from_fat  total_fat  saturated_fat  trans_fat  cholesterol  \
# 0              210.0       23.0            8.0        0.0         55.0
# 1              430.0       48.0           15.0        1.0         90.0
# 2              560.0       63.0           22.0        1.0        160.0
# 3              240.0       26.0            9.0        0.0         65.0
# 4              110.0       12.0            4.5        0.0         40.0
#
#    sodium  total_carbohydrates  dietary_fiber  sugars  protein
# 0  1350.0                 40.0            3.0     5.0     21.0
# 1  2540.0                 79.0            5.0    10.0     38.0
# 2  3760.0                115.0            8.0    13.0     61.0
# 3  1240.0                 37.0            1.0     3.0     18.0
# 4   980.0                 37.0            2.0     4.0     20.0

# %%
#adding values to blank columns
quiznos_df_reordered['restaurant_name'] = 'Quiznos'
quiznos_df_reordered['bread_type'] = 'Bread is a white baguette unless otherwise noted in the description'

quiznos_df_reordered.head()
# Out:
#   restaurant_name                                      sandwich_name  \
# 0         Quiznos  Classic Italian - with capicola, salami, ham, ...
# 1         Quiznos  Classic Italian - with capicola, salami, ham, ...
# 2         Quiznos  Classic Italian - with capicola, salami, ham, ...
# 3         Quiznos  Classic Italian - with capicola, salami, ham, ...
# 4         Quiznos  Turkey Ranch & Swiss - with lettuce, tomatoes,...
#
#   sandwich_description sandwich_length  \
# 0                               4" Sub
# 1                               8" Sub
# 2                              12" Sub
# 3                               Sammie
# 4                               4" Sub
#
#                                           bread_type  calories  \
# 0  Bread is a white baguette unless otherwise not...     450.0
# 1  Bread is a white baguette unless otherwise not...     890.0
# 2  Bread is a white baguette unless otherwise not...    1260.0
# 3  Bread is a white baguette unless otherwise not...     330.0
# 4  Bread is a white baguette unless otherwise not...     340.0
#
#    calories_from_fat  total_fat  saturated_fat  trans_fat  cholesterol  \
# 0              210.0       23.0            8.0        0.0         55.0
# 1              430.0       48.0           15.0        1.0         90.0
# 2              560.0       63.0           22.0        1.0        160.0
# 3              240.0       26.0            9.0        0.0         65.0
# 4              110.0       12.0            4.5        0.0         40.0
#
#    sodium  total_carbohydrates  dietary_fiber  sugars  protein
# 0  1350.0                 40.0            3.0     5.0     21.0
# 1  2540.0                 79.0            5.0    10.0     38.0
# 2  3760.0                115.0            8.0    13.0     61.0
# 3  1240.0                 37.0            1.0     3.0     18.0
# 4   980.0                 37.0            2.0     4.0     20.0

# %%
#splitting information

new = quiznos_df_reordered["sandwich_name"].str.split("-", n = 1, expand = True)
new
# Out:
#                            0  \
# 0           Classic Italian
# 1           Classic Italian
# 2           Classic Italian
# 3           Classic Italian
# 4      Turkey Ranch & Swiss
# ..                       ...
# 74  Lobster & Seafood Salad
# 75  Lobster & Seafood Salad
# 76  Lobster & Seafood Salad
# 77  Lobster & Seafood Salad
# 78  Lobster & Seafood Salad
#
#                                                     1
# 0    with capicola, salami, ham, pepperoni, provol...
# 1    with capicola, salami, ham, pepperoni, provol...
# 2    with capicola, salami, ham, pepperoni, provol...
# 3    with capicola, salami, ham, pepperoni, provol...
# 4                      with lettuce, tomatoes, onions
# ..                                                ...
# 74     with lobster & seafood salad, shredded lettuce
# 75     with lobster & seafood salad, shredded lettuce
# 76     with lobster & seafood salad, shredded lettuce
# 77     with lobster & seafood salad, shredded lettuce
# 78     with lobster & seafood salad, shredded lettuce
#
# [131 rows x 2 columns]

# %%
#drop sandwich name and description column\
quiznos_df_reordered = quiznos_df_reordered.drop(columns = ['sandwich_name', 'sandwich_description'])

quiznos_df_reordered
# Out:
#    restaurant_name sandwich_length  \
# 0          Quiznos          4" Sub
# 1          Quiznos          8" Sub
# 2          Quiznos         12" Sub
# 3          Quiznos          Sammie
# 4          Quiznos          4" Sub
# ..             ...             ...
# 74         Quiznos          4" Sub
# 75         Quiznos          8" Sub
# 76         Quiznos         12" Sub
# 77         Quiznos          Sammie
# 78         Quiznos      Half Salad
#
#                                            bread_type  calories  \
# 0   Bread is a white baguette unless otherwise not...     450.0
# 1   Bread is a white baguette unless otherwise not...     890.0
# 2   Bread is a white baguette unless otherwise not...    1260.0
# 3   Bread is a white baguette unless otherwise not...     330.0
# 4   Bread is a white baguette unless otherwise not...     340.0
# ..                                                ...       ...
# 74  Bread is a white baguette unless otherwise not...     300.0
# 75  Bread is a white baguette unless otherwise not...     610.0
# 76  Bread is a white baguette unless otherwise not...     910.0
# 77  Bread is a white baguette unless otherwise not...     300.0
# 78  Bread is a white baguette unless otherwise not...     300.0
#
#     calories_from_fat  total_fat  saturated_fat  trans_fat  cholesterol  \
# 0               210.0       23.0            8.0        0.0         55.0
# 1               430.0       48.0           15.0        1.0         90.0
# 2               560.0       63.0           22.0        1.0        160.0
# 3               240.0       26.0            9.0        0.0         65.0
# 4               110.0       12.0            4.5        0.0         40.0
# ..                ...        ...            ...        ...          ...
# 74              100.0       11.0            5.0        0.0         35.0
# 75              200.0       22.0           10.0        0.5         70.0
# 76              300.0       33.0           15.0        1.0        100.0
# 77              120.0       13.0            5.0        0.0         35.0
# 78              220.0       24.0            4.0        0.0         40.0
#
#     sodium  total_carbohydrates  dietary_fiber  sugars  protein
# 0   1350.0                 40.0            3.0     5.0     21.0
# 1   2540.0                 79.0            5.0    10.0     38.0
# 2   3760.0                115.0            8.0    13.0     61.0
# 3   1240.0                 37.0            1.0     3.0     18.0
# 4    980.0                 37.0            2.0     4.0     20.0
# ..     ...                  ...            ...     ...      ...
# 74   850.0                 40.0            2.0     3.0     12.0
# 75  1690.0                 80.0            5.0     6.0     24.0
# 76  2540.0                120.0            7.0    10.0     35.0
# 77   810.0                 34.0            4.0     3.0     11.0
# 78   980.0                 12.0            3.0     4.0      8.0
#
# [131 rows x 14 columns]

# %%
#join the dfs

quiznos_final = quiznos_df_reordered.join(new, how ='outer')

quiznos_final
# Out:
#    restaurant_name sandwich_length  \
# 0          Quiznos          4" Sub
# 0          Quiznos          4" Sub
# 0          Quiznos          4" Sub
# 0          Quiznos          4" Sub
# 0          Quiznos          4" Sub
# ..             ...             ...
# 74         Quiznos          4" Sub
# 75         Quiznos          8" Sub
# 76         Quiznos         12" Sub
# 77         Quiznos          Sammie
# 78         Quiznos      Half Salad
#
#                                            bread_type  calories  \
# 0   Bread is a white baguette unless otherwise not...     450.0
# 0   Bread is a white baguette unless otherwise not...     450.0
# 0   Bread is a white baguette unless otherwise not...     450.0
# 0   Bread is a white baguette unless otherwise not...     370.0
# 0   Bread is a white baguette unless otherwise not...     370.0
# ..                                                ...       ...
# 74  Bread is a white baguette unless otherwise not...     300.0
# 75  Bread is a white baguette unless otherwise not...     610.0
# 76  Bread is a white baguette unless otherwise not...     910.0
# 77  Bread is a white baguette unless otherwise not...     300.0
# 78  Bread is a white baguette unless otherwise not...     300.0
#
#     calories_from_fat  total_fat  saturated_fat  trans_fat  cholesterol  \
# 0               210.0       23.0            8.0        0.0         55.0
# 0               210.0       23.0            8.0        0.0         55.0
# 0               210.0       23.0            8.0        0.0         55.0
# 0               130.0       14.0            6.0        0.0         50.0
# 0               130.0       14.0            6.0        0.0         50.0
# ..                ...        ...            ...        ...          ...
# 74              100.0       11.0            5.0        0.0         35.0
# 75              200.0       22.0           10.0        0.5         70.0
# 76              300.0       33.0           15.0        1.0        100.0
# 77              120.0       13.0            5.0        0.0         35.0
# 78              220.0       24.0            4.0        0.0         40.0
#
#     sodium  total_carbohydrates  dietary_fiber  sugars  protein  \
# 0   1350.0                 40.0            3.0     5.0     21.0
# 0   1350.0                 40.0            3.0     5.0     21.0
# 0   1350.0                 40.0            3.0     5.0     21.0
# 0   1200.0                 37.0            2.0     4.0     23.0
# 0   1200.0                 37.0            2.0     4.0     23.0
# ..     ...                  ...            ...     ...      ...
# 74   850.0                 40.0            2.0     3.0     12.0
# 75  1690.0                 80.0            5.0     6.0     24.0
# 76  2540.0                120.0            7.0    10.0     35.0
# 77   810.0                 34.0            4.0     3.0     11.0
# 78   980.0                 12.0            3.0     4.0      8.0
#
#                            0  \
# 0           Classic Italian
# 0      Ultimate Turkey Club
# 0    Black Angus Steakhouse
# 0           Classic Italian
# 0      Ultimate Turkey Club
# ..                       ...
# 74  Lobster & Seafood Salad
# 75  Lobster & Seafood Salad
# 76  Lobster & Seafood Salad
# 77  Lobster & Seafood Salad
# 78  Lobster & Seafood Salad
#
#                                                     1
# 0    with capicola, salami, ham, pepperoni, provol...
# 0    with bacon, cheddar, lettuce, tomatoes, mayo ...
# 0    with provolone, cheddar, sauteed mushrooms & ...
# 0    with capicola, salami, ham, pepperoni, provol...
# 0    with bacon, cheddar, lettuce, tomatoes, mayo ...
# ..                                                ...
# 74     with lobster & seafood salad, shredded lettuce
# 75     with lobster & seafood salad, shredded lettuce
# 76     with lobster & seafood salad, shredded lettuce
# 77     with lobster & seafood salad, shredded lettuce
# 78     with lobster & seafood salad, shredded lettuce
#
# [279 rows x 16 columns]

# %%
# Out:
#    restaurant_name             sandwich_name  \
# 0          Quiznos          Classic Italian
# 0          Quiznos     Ultimate Turkey Club
# 0          Quiznos   Black Angus Steakhouse
# 0          Quiznos          Classic Italian
# 0          Quiznos     Ultimate Turkey Club
# ..             ...                       ...
# 74         Quiznos  Lobster & Seafood Salad
# 75         Quiznos  Lobster & Seafood Salad
# 76         Quiznos  Lobster & Seafood Salad
# 77         Quiznos  Lobster & Seafood Salad
# 78         Quiznos  Lobster & Seafood Salad
#
#                                  sandwich_description sandwich_length  \
# 0    with capicola, salami, ham, pepperoni, provol...          4" Sub
# 0    with bacon, cheddar, lettuce, tomatoes, mayo ...          4" Sub
# 0    with provolone, cheddar, sauteed mushrooms & ...          4" Sub
# 0    with capicola, salami, ham, pepperoni, provol...          4" Sub
# 0    with bacon, cheddar, lettuce, tomatoes, mayo ...          4" Sub
# ..                                                ...             ...
# 74     with lobster & seafood salad, shredded lettuce          4" Sub
# 75     with lobster & seafood salad, shredded lettuce          8" Sub
# 76     with lobster & seafood salad, shredded lettuce         12" Sub
# 77     with lobster & seafood salad, shredded lettuce          Sammie
# 78     with lobster & seafood salad, shredded lettuce      Half Salad
#
#                                            bread_type  calories  \
# 0   Bread is a white baguette unless otherwise not...     450.0
# 0   Bread is a white baguette unless otherwise not...     450.0
# 0   Bread is a white baguette unless otherwise not...     450.0
# 0   Bread is a white baguette unless otherwise not...     370.0
# 0   Bread is a white baguette unless otherwise not...     370.0
# ..                                                ...       ...
# 74  Bread is a white baguette unless otherwise not...     300.0
# 75  Bread is a white baguette unless otherwise not...     610.0
# 76  Bread is a white baguette unless otherwise not...     910.0
# 77  Bread is a white baguette unless otherwise not...     300.0
# 78  Bread is a white baguette unless otherwise not...     300.0
#
#     calories_from_fat  total_fat  saturated_fat  trans_fat  cholesterol  \
# 0               210.0       23.0            8.0        0.0         55.0
# 0               210.0       23.0            8.0        0.0         55.0
# 0               210.0       23.0            8.0        0.0         55.0
# 0               130.0       14.0            6.0        0.0         50.0
# 0               130.0       14.0            6.0        0.0         50.0
# ..                ...        ...            ...        ...          ...
# 74              100.0       11.0            5.0        0.0         35.0
# 75              200.0       22.0           10.0        0.5         70.0
# 76              300.0       33.0           15.0        1.0        100.0
# 77              120.0       13.0            5.0        0.0         35.0
# 78              220.0       24.0            4.0        0.0         40.0
#
#     sodium  total_carbohydrates  dietary_fiber  sugars  protein
# 0   1350.0                 40.0            3.0     5.0     21.0
# 0   1350.0                 40.0            3.0     5.0     21.0
# 0   1350.0                 40.0            3.0     5.0     21.0
# 0   1200.0                 37.0            2.0     4.0     23.0
# 0   1200.0                 37.0            2.0     4.0     23.0
# ..     ...                  ...            ...     ...      ...
# 74   850.0                 40.0            2.0     3.0     12.0
# 75  1690.0                 80.0            5.0     6.0     24.0
# 76  2540.0                120.0            7.0    10.0     35.0
# 77   810.0                 34.0            4.0     3.0     11.0
# 78   980.0                 12.0            3.0     4.0      8.0
#
# [279 rows x 16 columns]
