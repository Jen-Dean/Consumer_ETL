# %%
#dependencies

#going to using beautifulsoup, then splinter,

from splinter import Browser
from bs4 import BeautifulSoup
from webdriver_manager.chrome import ChromeDriverManager
import requests


#Main GOAL: scraping subway nutritional facts

# %%
#splinter 
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# [WDM] - Current google-chrome version is 86.0.4240
# [WDM] - Get LATEST driver version for 86.0.4240
# [WDM] - Driver [/Users/sherinm/.wdm/drivers/chromedriver/mac64/86.0.4240.22/chromedriver] found in cache

# %%
#url of page needed 
#SUBWAY url that I need

url = 'https://fastfoodnutrition.org/subway'

#browse subway url

browser.visit(url)

# %%
print(soup.prettify())
# Out:
# <html lang="en">
#  <head>
#   <link as="style" href="https://fonts.googleapis.com/css?family=Open+Sans:300,400,700&amp;display=swap" rel="preload"/>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta content="FastFoodNutrition.org" property="og:site_name"/>
#   <meta content="Website" property="og:type"/>
#   <meta content="https://fastfoodnutrition.org/subway" property="og:url"/>
#   <meta content="https://fastfoodnutrition.org/subway" property="twitter:url"/>
#   <link href="https://fastfoodnutrition.org/favicon.png" rel="icon" sizes="16x16" type="image/png"/>
#   <meta content="uwY4KDvAqjtaNa915c-BSMoZL72Q-vDvBDAn45cmYDA" name="google-site-verification"/>
#   <meta content="510431215760752" property="fb:app_id"/>
#   <link href="https://fastfoodnutrition.org/ca/subway" hreflang="en-CA" rel="alternate"/>
#   <link href="https://fastfoodnutrition.org/subway" rel="canonical"/>
#   <meta content="https://fastfoodnutrition.org/logos/subway.jpg" property="og:image"/>
#   <meta content="https://fastfoodnutrition.org/logos/subway.jpg" property="twitter:image"/>
#   <meta content="Nutrition facts for the full Subway Sandwiches  menu, including calories,carbs, sodium and Weight Watchers points." name="description"/>
#   <meta content="Nutrition facts for the full Subway Sandwiches  menu, including calories,carbs, sodium and Weight Watchers points." property="og:description"/>
#   <meta content="Nutrition facts for the full Subway Sandwiches  menu, including calories,carbs, sodium and Weight Watchers points." property="twitter:description"/>
#   <meta content="Subway Nutrition Facts" property="og:title"/>
#   <title>
#    Subway Nutrition Facts
#   </title>
#   <script async="" src="https://www.google-analytics.com/analytics.js" type="text/javascript">
#   </script>
#   <script async="" src="//c.amazon-adsystem.com/aax2/apstag.js">
#   </script>
#   <script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-TTZ59GL&amp;gtm_auth=sgIpway-MsYi3RH24laOgQ&amp;gtm_preview=env-2&amp;gtm_cookies_win=x">
#   </script>
#   <script>
#    dataLayer = [{
# 'ab' : '0', 'restaurant' : 'subway', 'destination' : 'restaurant', 'landing_page' : 'restaurant'
# }];
#   </script>
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl+ '&gtm_auth=sgIpway-MsYi3RH24laOgQ&gtm_preview=env-2&gtm_cookies_win=x';f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-TTZ59GL');
#   </script>
#   <!--[if lt IE 9]>
#       <script src="https://oss.maxcdn.com/libs/html5shiv/3.7.0/html5shiv.js"></script>
#       <script src="https://oss.maxcdn.com/libs/respond.js/1.4.2/respond.min.js"></script>
#     <![endif]-->
#   <link href="/css/1.0.97/ffn.css" rel="stylesheet"/>
#   <script async="" data-cookieconsent="statistics" src="//www.googletagservices.com/tag/js/gpt.js">
#   </script>
#   <script async="" data-cookieconsent="marketing" src="/js/prebid4.16.0.js" type="text/javascript">
#   </script>
#   <script data-cookieconsent="marketing">
#    var amz_ibids = 0;
# var prebid_ibids = 0;
#
# 	var bottom_offset = 250;
#     var PREBID_TIMEOUT = 1000;
# 	var FAILSAFE_TIMEOUT = 1200;
# 	var googletag = googletag || {};
# 	googletag.cmd = googletag.cmd || [];
#
# 	var pbjs = pbjs || {};
# 	pbjs.que = pbjs.que || [];
#
#
# var slots = new Object();
#
#
#
# 	var slot_mobile0;
#
#             googletag.cmd.push(function() {
#
#                 slot_mobile0 = googletag.defineSlot('/50970423/ffn-hb-mo-5', [[320, 50]], 'div-gpt-ad-1553745877806-0')
#                 	.addService(googletag.pubads());
#                 googletag.pubads().disableInitialLoad();
#                 googletag.pubads().enableSingleRequest();
#                 googletag.enableServices();
#
# 			slots['/50970423/ffn-hb-mo-5'] = slot_mobile0;
#             });
#
#
# 	var slot_mobile1;
#
#             googletag.cmd.push(function() {
#
#                 slot_mobile1 = googletag.defineSlot('/50970423/ffn-hb-mo-4', [[320, 50]], 'div-gpt-ad-1553745800846-0')
#                 	.addService(googletag.pubads());
#                 googletag.pubads().disableInitialLoad();
#                 googletag.pubads().enableSingleRequest();
#                 googletag.enableServices();
#
# 			slots['/50970423/ffn-hb-mo-4'] = slot_mobile1;
#             });
#
#
# 	var slot_mobile2;
#
#             googletag.cmd.push(function() {
#
#                 slot_mobile2 = googletag.defineSlot('/50970423/ffn-hb-mo-3', [[320, 50]], 'div-gpt-ad-1553745709569-0')
#                 	.addService(googletag.pubads());
#                 googletag.pubads().disableInitialLoad();
#                 googletag.pubads().enableSingleRequest();
#                 googletag.enableServices();
#
# 			slots['/50970423/ffn-hb-mo-3'] = slot_mobile2;
#             });
#
#
# 	var slot_mobile3;
#
#             googletag.cmd.push(function() {
#
#                 slot_mobile3 = googletag.defineSlot('/50970423/ffn-hb-mo-2', [[320, 50]], 'div-gpt-ad-1553745651217-0')
#                 	.addService(googletag.pubads());
#                 googletag.pubads().disableInitialLoad();
#                 googletag.pubads().enableSingleRequest();
#                 googletag.enableServices();
#
# 			slots['/50970423/ffn-hb-mo-2'] = slot_mobile3;
#             });
#
#
# 	var slot_mobile4;
#
#             googletag.cmd.push(function() {
#
#                 slot_mobile4 = googletag.defineSlot('/50970423/ffn-hb-mo-1', [[320, 50]], 'div-gpt-ad-1553745517306-0')
#                 	.addService(googletag.pubads());
#                 googletag.pubads().disableInitialLoad();
#                 googletag.pubads().enableSingleRequest();
#                 googletag.enableServices();
#
# 			slots['/50970423/ffn-hb-mo-1'] = slot_mobile4;
#             });
#
#
# 	var slot_leader0;
#
#             googletag.cmd.push(function() {
#
#                 slot_leader0 = googletag.defineSlot('/50970423/ffn-hb-leader', [[728, 90]], 'div-gpt-ad-1487628416738-0')
#                 	.addService(googletag.pubads());
#                 googletag.pubads().disableInitialLoad();
#                 googletag.pubads().enableSingleRequest();
#                 googletag.enableServices();
#
# 			slots['/50970423/ffn-hb-leader'] = slot_leader0;
#             });
#
#
# 	var slot_rect0;
#
#             googletag.cmd.push(function() {
#
#                 slot_rect0 = googletag.defineSlot('/50970423/ffn-hb-rect-1', [[300, 250]], 'div-gpt-ad-1487305430432-0')
#                 	.addService(googletag.pubads());
#                 googletag.pubads().disableInitialLoad();
#                 googletag.pubads().enableSingleRequest();
#                 googletag.enableServices();
#
# 			slots['/50970423/ffn-hb-rect-1'] = slot_rect0;
#             });
#
#
# 	var slot_rect1;
#
#             googletag.cmd.push(function() {
#
#                 slot_rect1 = googletag.defineSlot('/50970423/ffn-hb-rect-2', [[300, 250],[300, 600]], 'div-gpt-ad-1487628416738-3')
#                 	.addService(googletag.pubads());
#                 googletag.pubads().disableInitialLoad();
#                 googletag.pubads().enableSingleRequest();
#                 googletag.enableServices();
#
# 			slots['/50970423/ffn-hb-rect-2'] = slot_rect1;
#             });
#
#
# 	var slot_rect2;
#
#             googletag.cmd.push(function() {
#
#                 slot_rect2 = googletag.defineSlot('/50970423/ffn-hb-rect-3', [[300, 250],[300, 600]], 'div-gpt-ad-1487628416738-4')
#                 	.addService(googletag.pubads());
#                 googletag.pubads().disableInitialLoad();
#                 googletag.pubads().enableSingleRequest();
#                 googletag.enableServices();
#
# 			slots['/50970423/ffn-hb-rect-3'] = slot_rect2;
#             });
#
#
# 	var slot_rect3;
#
#             googletag.cmd.push(function() {
#
#                 slot_rect3 = googletag.defineSlot('/50970423/ffn-hb-rect-4', [[300, 250]], 'div-gpt-ad-1600282375298-0')
#                 	.addService(googletag.pubads());
#                 googletag.pubads().disableInitialLoad();
#                 googletag.pubads().enableSingleRequest();
#                 googletag.enableServices();
#
# 			slots['/50970423/ffn-hb-rect-4'] = slot_rect3;
#             });
#
#
# 	var slot_rect4;
#
#             googletag.cmd.push(function() {
#
#                 slot_rect4 = googletag.defineSlot('/50970423/ffn-hb-rect-ex', [[300, 250]], 'div-gpt-ad-1600282464548-0')
#                 	.addService(googletag.pubads());
#                 googletag.pubads().disableInitialLoad();
#                 googletag.pubads().enableSingleRequest();
#                 googletag.enableServices();
#
# 			slots['/50970423/ffn-hb-rect-ex'] = slot_rect4;
#             });
#
#
# 	var slot_desktop_footer0;
#
#             googletag.cmd.push(function() {
#
#                 slot_desktop_footer0 = googletag.defineSlot('/50970423/ffn-hb-desktop-footer', [[728, 90]], 'div-gpt-ad-1554247110074-0')
#                 	.addService(googletag.pubads());
#                 googletag.pubads().disableInitialLoad();
#                 googletag.pubads().enableSingleRequest();
#                 googletag.enableServices();
#
# 			slots['/50970423/ffn-hb-desktop-footer'] = slot_desktop_footer0;
#             });
#
#
# 	//load the apstag.js library
# !function(a9,a,p,s,t,A,g){if(a[a9])return;function q(c,r){a[a9]._Q.push([c,r])}a[a9]={init:function(){q("i",arguments)},fetchBids:function(){q("f",arguments)},setDisplayBids:function(){},targetingKeys:function(){return[]},_Q:[]};A=p.createElement(s);A.async=!0;A.src=t;g=p.getElementsByTagName(s)[0];g.parentNode.insertBefore(A,g)}("apstag",window,document,"script","//c.amazon-adsystem.com/aax2/apstag.js");
#
# //initialize the apstag.js library on the page to allow bidding
# apstag.init({
#      pubID: '6190bc8e-ee15-427f-8879-92f96b529daf', //enter your pub ID here as shown above, it must within quotes
#      adServer: 'googletag'
# });
# apstag.fetchBids({
#      slots: [,
# 		{
#          slotID: 'div-gpt-ad-1487628416738-0',
#          slotName: '/50970423/ffn-hb-leader',
#          sizes: [[728, 90]]
#      },
# 		{
#          slotID: 'div-gpt-ad-1487305430432-0',
#          slotName: '/50970423/ffn-hb-rect-1',
#          sizes: [[300, 250]]
#      },
# 		{
#          slotID: 'div-gpt-ad-1487628416738-3',
#          slotName: '/50970423/ffn-hb-rect-2',
#          sizes: [[300, 250],[300, 600]]
#      },
# 		{
#          slotID: 'div-gpt-ad-1554247110074-0',
#          slotName: '/50970423/ffn-hb-desktop-footer',
#          sizes: [[728, 90]]
#      }],
#      timeout: 2e3
# }, function(bids) {
#      // set apstag targeting on googletag, then trigger the first DFP request in googletag's disableInitialLoad integration
#      googletag.cmd.push(function(){
#          apstag.setDisplayBids();
#         // googletag.pubads().refresh();
# 		//console.log('initial amazon');
# 		amz_ibids = 1;
# 		checkForBids();
# 		//console.log('amz bids returned' + Date.now());
#      });
# });
# 		//console.log('doing thing after amz' + Date.now());
#
#
#
#
#     var adUnits = [{
#         code: '/50970423/ffn-hb-mo-5',
# 		mediaTypes: {
# 			banner: {
# 				sizes: [[320, 50]]
# 				}
# 			}, bids: [{
# 				bidder: 'districtmDMX',
# 				params: {
# 					dmxid: 145522,
# 					memberid: 100692
# 				}
# 			},
# 			{
# 				bidder: 'amx',
# 				params: {}
# 			},
#
# 			{
# 				bidder: 'sovrn',
# 				params: {
# 					tagid: '605462'
# 				}
# 			},
# 			{
# 				bidder: 'conversant',
# 				params: {
# 					site_id: '109769',
# 					secure: '1'
# 				}
# 			},
#
# 			{
# 				bidder: 'districtm',
# 				params: {
# 					placementId: '10954820'
# 				}
#
# 			},
# 			{
# 				bidder: 'aol',
# 				params: {
# 					network: '10966.1',
# 					placement: '5068043'
# 				}
# 			}
# 			]},{
#
#         code: '/50970423/ffn-hb-mo-4',
# 		mediaTypes: {
# 			banner: {
# 				sizes: [[320, 50]]
# 				}
# 			}, bids: [{
# 				bidder: 'districtmDMX',
# 				params: {
# 					dmxid: 145522,
# 					memberid: 100692
# 				}
# 			},
# 			{
# 				bidder: 'amx',
# 				params: {}
# 			},
#
# 			{
# 				bidder: 'sovrn',
# 				params: {
# 					tagid: '605462'
# 				}
# 			},
# 			{
# 				bidder: 'conversant',
# 				params: {
# 					site_id: '109769',
# 					secure: '1'
# 				}
# 			},
#
# 			{
# 				bidder: 'districtm',
# 				params: {
# 					placementId: '10954820'
# 				}
#
# 			},
# 			{
# 				bidder: 'aol',
# 				params: {
# 					network: '10966.1',
# 					placement: '5068043'
# 				}
# 			}
# 			]},{
#
#         code: '/50970423/ffn-hb-mo-3',
# 		mediaTypes: {
# 			banner: {
# 				sizes: [[320, 50]]
# 				}
# 			}, bids: [{
# 				bidder: 'districtmDMX',
# 				params: {
# 					dmxid: 145522,
# 					memberid: 100692
# 				}
# 			},
# 			{
# 				bidder: 'amx',
# 				params: {}
# 			},
#
# 			{
# 				bidder: 'sovrn',
# 				params: {
# 					tagid: '605462'
# 				}
# 			},
# 			{
# 				bidder: 'conversant',
# 				params: {
# 					site_id: '109769',
# 					secure: '1'
# 				}
# 			},
#
# 			{
# 				bidder: 'districtm',
# 				params: {
# 					placementId: '10954820'
# 				}
#
# 			},
# 			{
# 				bidder: 'aol',
# 				params: {
# 					network: '10966.1',
# 					placement: '5068043'
# 				}
# 			}
# 			]},{
#
#         code: '/50970423/ffn-hb-mo-2',
# 		mediaTypes: {
# 			banner: {
# 				sizes: [[320, 50]]
# 				}
# 			}, bids: [{
# 				bidder: 'districtmDMX',
# 				params: {
# 					dmxid: 145522,
# 					memberid: 100692
# 				}
# 			},
# 			{
# 				bidder: 'amx',
# 				params: {}
# 			},
#
# 			{
# 				bidder: 'sovrn',
# 				params: {
# 					tagid: '605462'
# 				}
# 			},
# 			{
# 				bidder: 'conversant',
# 				params: {
# 					site_id: '109769',
# 					secure: '1'
# 				}
# 			},
#
# 			{
# 				bidder: 'districtm',
# 				params: {
# 					placementId: '10954820'
# 				}
#
# 			},
# 			{
# 				bidder: 'aol',
# 				params: {
# 					network: '10966.1',
# 					placement: '5068043'
# 				}
# 			}
# 			]},{
#
#         code: '/50970423/ffn-hb-mo-1',
# 		mediaTypes: {
# 			banner: {
# 				sizes: [[320, 50]]
# 				}
# 			}, bids: [{
# 				bidder: 'districtmDMX',
# 				params: {
# 					dmxid: 145522,
# 					memberid: 100692
# 				}
# 			},
# 			{
# 				bidder: 'amx',
# 				params: {}
# 			},
#
# 			{
# 				bidder: 'sovrn',
# 				params: {
# 					tagid: '605462'
# 				}
# 			},
# 			{
# 				bidder: 'conversant',
# 				params: {
# 					site_id: '109769',
# 					secure: '1'
# 				}
# 			},
#
# 			{
# 				bidder: 'districtm',
# 				params: {
# 					placementId: '10954820'
# 				}
#
# 			},
# 			{
# 				bidder: 'aol',
# 				params: {
# 					network: '10966.1',
# 					placement: '5068043'
# 				}
# 			}
# 			]},{
#
#         code: '/50970423/ffn-hb-leader',
# 		mediaTypes: {
# 			banner: {
# 				sizes: [[728, 90]]
# 				}
# 			}, bids: [{
# 				bidder: 'districtmDMX',
# 				params: {
# 					dmxid: 145522,
# 					memberid: 100692
# 				}
# 			},
# 			{
# 				bidder: 'amx',
# 				params: {}
# 			},
# 			{
# 				bidder: 'aol',
# 				params: {
# 					network: '10966.1',
# 					placement: '4489118'
# 				}
# 			},
#
# 			{
# 				bidder: 'districtm',
# 				params: {
# 					placementId: '10954820'
# 				}
#
# 			},
#
# 			{
# 				bidder: 'sovrn',
# 				params: {
# 					tagid: '440953'
# 				}
# 			},
# 			{
# 				bidder: 'conversant',
# 				params: {
# 					site_id: '109769',
# 					secure: '1'
# 				}
# 			}
# 			]},{
#
#         code: '/50970423/ffn-hb-rect-1',
# 		mediaTypes: {
# 			banner: {
# 				sizes: [[300, 250]]
# 				}
# 			}, bids: [{
# 				bidder: 'districtmDMX',
# 				params: {
# 					dmxid: 145522,
# 					memberid: 100692
# 				}
# 			},
# 			{
# 				bidder: 'amx',
# 				params: {}
# 			},
# 			{
# 				bidder: 'aol',
# 				params: {
# 					network: '10966.1',
# 					placement: '4489117'
# 				}
# 			},
#
# 			{
# 				bidder: 'districtm',
# 				params: {
# 					placementId: '10954820'
# 				}
#
# 			},
#
#
# 			{
# 				bidder: 'sovrn',
# 				params: {
# 					tagid: '440152'
# 				}
# 			},
# 			{
# 				bidder: 'conversant',
# 				params: {
# 					site_id: '109769',
# 					secure: '1'
# 				}
# 			}]},{
#
#         code: '/50970423/ffn-hb-rect-2',
# 		mediaTypes: {
# 			banner: {
# 				sizes: [[300, 250],[300, 600]]
# 				}
# 			}, bids: [{
# 				bidder: 'districtmDMX',
# 				params: {
# 					dmxid: 145522,
# 					memberid: 100692
# 				}
# 			},
# 			{
# 				bidder: 'amx',
# 				params: {}
# 			},
# 			{
# 				bidder: 'aol',
# 				params: {
# 					network: '10966.1',
# 					placement: '4489117'
# 				}
# 			},
#
# 			{
# 				bidder: 'districtm',
# 				params: {
# 					placementId: '10954820'
# 				}
#
# 			},
#
#
# 			{
# 				bidder: 'sovrn',
# 				params: {
# 					tagid: '440152'
# 				}
# 			},
# 			{
# 				bidder: 'conversant',
# 				params: {
# 					site_id: '109769',
# 					secure: '1'
# 				}
# 			},{
#                                 bidder: 'sovrn',
#                                 params: {
#                                         tagid: '582218'
#                                 }
# 							}]},{
#
#         code: '/50970423/ffn-hb-rect-3',
# 		mediaTypes: {
# 			banner: {
# 				sizes: [[300, 250],[300, 600]]
# 				}
# 			}, bids: [{
# 				bidder: 'districtmDMX',
# 				params: {
# 					dmxid: 145522,
# 					memberid: 100692
# 				}
# 			},
# 			{
# 				bidder: 'amx',
# 				params: {}
# 			},
# 			{
# 				bidder: 'aol',
# 				params: {
# 					network: '10966.1',
# 					placement: '4489117'
# 				}
# 			},
#
# 			{
# 				bidder: 'districtm',
# 				params: {
# 					placementId: '10954820'
# 				}
#
# 			},
#
#
# 			{
# 				bidder: 'sovrn',
# 				params: {
# 					tagid: '440152'
# 				}
# 			},
# 			{
# 				bidder: 'conversant',
# 				params: {
# 					site_id: '109769',
# 					secure: '1'
# 				}
# 			},{
#                                 bidder: 'sovrn',
#                                 params: {
#                                         tagid: '582218'
#                                 }
# 							}]},{
#
#         code: '/50970423/ffn-hb-rect-4',
# 		mediaTypes: {
# 			banner: {
# 				sizes: [[300, 250]]
# 				}
# 			}, bids: [{
# 				bidder: 'districtmDMX',
# 				params: {
# 					dmxid: 145522,
# 					memberid: 100692
# 				}
# 			},
# 			{
# 				bidder: 'amx',
# 				params: {}
# 			},
# 			{
# 				bidder: 'aol',
# 				params: {
# 					network: '10966.1',
# 					placement: '4489117'
# 				}
# 			},
#
# 			{
# 				bidder: 'districtm',
# 				params: {
# 					placementId: '10954820'
# 				}
#
# 			},
#
#
# 			{
# 				bidder: 'sovrn',
# 				params: {
# 					tagid: '440152'
# 				}
# 			},
# 			{
# 				bidder: 'conversant',
# 				params: {
# 					site_id: '109769',
# 					secure: '1'
# 				}
# 			}]},{
#
#         code: '/50970423/ffn-hb-rect-ex',
# 		mediaTypes: {
# 			banner: {
# 				sizes: [[300, 250]]
# 				}
# 			}, bids: [{
# 				bidder: 'districtmDMX',
# 				params: {
# 					dmxid: 145522,
# 					memberid: 100692
# 				}
# 			},
# 			{
# 				bidder: 'amx',
# 				params: {}
# 			},
# 			{
# 				bidder: 'aol',
# 				params: {
# 					network: '10966.1',
# 					placement: '4489117'
# 				}
# 			},
#
# 			{
# 				bidder: 'districtm',
# 				params: {
# 					placementId: '10954820'
# 				}
#
# 			},
#
#
# 			{
# 				bidder: 'sovrn',
# 				params: {
# 					tagid: '440152'
# 				}
# 			},
# 			{
# 				bidder: 'conversant',
# 				params: {
# 					site_id: '109769',
# 					secure: '1'
# 				}
# 			}]},{
#
#         code: '/50970423/ffn-hb-desktop-footer',
# 		mediaTypes: {
# 			banner: {
# 				sizes: [[728, 90]]
# 				}
# 			}, bids: [{
# 				bidder: 'districtmDMX',
# 				params: {
# 					dmxid: 145522,
# 					memberid: 100692
# 				}
# 			},
# 			{
# 				bidder: 'amx',
# 				params: {
# 				}
# 			},
#
# 			{
# 				bidder: 'aol',
# 				params: {
# 					network: '10966.1',
# 					placement: '4489118'
# 				}
# 			},
#
# 			{
# 				bidder: 'districtm',
# 				params: {
# 					placementId: '10954820'
# 				}
#
# 			},
#
# 			{
# 				bidder: 'sovrn',
# 				params: {
# 					tagid: '440953'
# 				}
# 			},
#
# 			{
# 				bidder: 'conversant',
# 				params: {
# 					site_id: '109769',
# 					secure: '1'
# 				}
# 			}
# 			]}];
#
#
# 		            pbjs.que.push(function() {
#
# 												const customConfigObject2 = {
# 	  "buckets" : [{
# 		  "precision": 2,
# 		  "min" : 0,
# 		  "max" : 22.50,
# 		  "increment" : 0.01
# 		}]
# 	};
#
# 						pbjs.setConfig({ priceGranularity: customConfigObject2});
#                 pbjs.addAdUnits(adUnits);
# 						pbjs.bidderSettings =
#
#
#
#
#
# {
#                 districtmDMX: {
#                     bidCpmAdjustment : function(bidCpm){
#                         return bidCpm / 0.9;
#                     }
#                 },
#                 ix: {
#                     bidCpmAdjustment : function(bidCpm){
#                         return bidCpm / 0.9;
#                     }
#                 },
#                 amx: {
#                     bidCpmAdjustment : function(bidCpm){
#                         return bidCpm / 0.9;
#                     }
#                 },
#                 aol: {
#                     bidCpmAdjustment : function(bidCpm){
#                         return bidCpm / 0.9;
#                     }
#                 },
#
#                 sovrn: {
#                     bidCpmAdjustment : function(bidCpm){
#                         return bidCpm / 0.9;
#                     }
#                 },
#                 conversant: {
#                     bidCpmAdjustment : function(bidCpm){
#                         return bidCpm / 0.9;
#                     }
#                 },
#                 districtm: {
#                     bidCpmAdjustment : function(bidCpm){
#                         return bidCpm * 0.944444;
#                     }
#                 }
#
# 	}
#
#
#
#
# ;});
#
#
#
#
#      function refreshBid(adUnitName,refresh) {
# var refreshval = refresh.toString();
# function sendAdserverRequestRefresh(adUnitName) {
# 		console.log("REFRESHT "+ adUnitName + "Loading ads");
# 	pbjs.setTargetingForGPTAsync([adUnitName]);
# 	googletag.pubads().setTargeting("reload", refreshval);
#
# 	googletag.pubads().refresh([slots[adUnitName]]);
# }
#
#
#   function checkForBidsRefresh(){
# 	console.log("REFRESHT "+ adUnitName + "checking for bids");
# 	  if(amz_refreshbids && prebid_refreshbids){
# 			console.log("REFRESHT "+ adUnitName + "bids are in!");
# 		  sendAdserverRequestRefresh(adUnitName);
# 	  }else{
# 		 	console.log("REFRESHT "+ adUnitName + "missing bids");
# 	  }
#
#
#   }
#
# 		 var prebid_refreshbids = 0;
# 		 var amz_refreshbids = 0;
# 		// alert('here' + adUnitName);
# 		console.log("REFRESHT "+ adUnitName + "starting");
# 	var amazon_name = adUnitName.replace(/-/g,"");
# 	console.log("amz" + amazon_lazy_bids[amazon_name][0]);
#
#
# 	console.log("REFRESHT "+ adUnitName + "starting amz bids");
# apstag.fetchBids({
#      slots: [{
#          slotID: amazon_lazy_bids[amazon_name][0],
#          slotName: adUnitName,
#          sizes: [[amazon_lazy_bids[amazon_name][2], amazon_lazy_bids[amazon_name][1]]]
#      }],
#      timeout: 2e3
# }, function(bids) {
#      // set apstag targeting on googletag, then trigger the first DFP request in googletag's disableInitialLoad integration
#      googletag.cmd.push(function(){
# 		 googletag.pubads().setTargeting("reload", refreshval);
#
#          apstag.setDisplayBids();
# 		 amz_refreshbids = 1;
# 		 	console.log("REFRESHT "+ adUnitName + "done amz bids");
# 		checkForBidsRefresh();
# 		console.log("REFRESHT "+ adUnitName + "we should be done with amz bids, check for bids should have started");
#
#         // googletag.pubads().refresh();
#      });
# });
#                pbjs.que.push(function() {
#
# 						const customConfigObject = {
# 	  "buckets" : [{
# 		  "precision": 2,
# 		  "min" : 0,
# 		  "max" : 22.50,
# 		  "increment" : 0.01
# 		}]
# 	};
#
#
#
# pbjs.setConfig({ priceGranularity: customConfigObject});
# 	console.log("REFRESHT "+ adUnitName + "starting prebid bids");
#                     pbjs.requestBids({
#                         timeout: PREBID_TIMEOUT,
#                         adUnitCodes: [adUnitName],
#                         bidsBackHandler: function() {
# 							console.log("REFRESHT "+ adUnitName + "done with prebid bids");
# 							prebid_refreshbids = 1;
# 							checkForBidsRefresh();
#
#
#  }
#                     });
#
# 				});
#             }
#
#
#
#           pbjs.que.push(function() {
# 			  pbjs.setConfig({
#     userSync: {
#         userIds: [{
#             name: "pubCommonId",
#             storage: {
#                 type: "cookie",
#                 name: "_pubcid",         // create a cookie with this name
#                 expires: 365             // expires in 1 years
#             }
#         }]
#     }
# });
#               pbjs.addAdUnits(adUnits);
#               pbjs.requestBids({
#                   adUnitCodes: ['/50970423/ffn-hb-leader', '/50970423/ffn-hb-rect-1', '/50970423/ffn-hb-rect-2', '/50970423/ffn-hb-desktop-footer'],
#                   bidsBackHandler: function(){
# 					  //console.log('setting prebid_ibids done');
# 						prebid_ibids = 1;
# 					  checkForBids();
# 				  }
#               });
#           });
#
#
#
# 		  function checkForBids(){
# 			 // console.log('checking for bids');
# 			  if(amz_ibids && prebid_ibids){
# 				 // console.log('all of our bids are in. Sending bids');
# 				  sendAdserverRequest();
# 			  }else{
# 				 // console.log('we are missing bids');
# 			  }
#
#
# 		  }
#
#
#
#           function sendAdserverRequest() {
#               if (pbjs.adserverRequestSent) return;
# 			  console.log('about to check bids');
#               pbjs.adserverRequestSent = true;
#               googletag.cmd.push(function() {
# 				  	googletag.pubads().setTargeting('experiment', 'desktop/tablet_control');
# 					googletag.pubads().setTargeting('page_type', 'rest.php');
#                   pbjs.que.push(function() {
#                       pbjs.setTargetingForGPTAsync(['/50970423/ffn-hb-leader', '/50970423/ffn-hb-rect-1', '/50970423/ffn-hb-rect-2', '/50970423/ffn-hb-desktop-footer']);
# 					  		 console.log('initial loadingad');
#                       googletag.pubads().refresh([slot_leader0, slot_rect0, slot_rect1, slot_desktop_footer0]);
#                   });});};
#
#           setTimeout(function() {
# 			  		 console.log('initial timeout done');
#               sendAdserverRequest();
#           }, FAILSAFE_TIMEOUT);
#
# 		  var amazon_lazy_bids = new Array();amazon_lazy_bids["/50970423/ffnhbmo5"] = ["div-gpt-ad-1553745877806-0","50","320"];
# 		amazon_lazy_bids["/50970423/ffnhbmo4"] = ["div-gpt-ad-1553745800846-0","50","320"];
# 		amazon_lazy_bids["/50970423/ffnhbmo3"] = ["div-gpt-ad-1553745709569-0","50","320"];
# 		amazon_lazy_bids["/50970423/ffnhbmo2"] = ["div-gpt-ad-1553745651217-0","50","320"];
# 		amazon_lazy_bids["/50970423/ffnhbmo1"] = ["div-gpt-ad-1553745517306-0","50","320"];
# 		amazon_lazy_bids["/50970423/ffnhbleader"] = ["div-gpt-ad-1487628416738-0","90","728"];
# 		amazon_lazy_bids["/50970423/ffnhbrect1"] = ["div-gpt-ad-1487305430432-0","250","300"];
# 		amazon_lazy_bids["/50970423/ffnhbrect2"] = ["div-gpt-ad-1487628416738-3","250","300"];
# 		amazon_lazy_bids["/50970423/ffnhbrect3"] = ["div-gpt-ad-1487628416738-4","250","300"];
# 		amazon_lazy_bids["/50970423/ffnhbrect4"] = ["div-gpt-ad-1600282375298-0","250","300"];
# 		amazon_lazy_bids["/50970423/ffnhbrectex"] = ["div-gpt-ad-1600282464548-0","250","300"];
# 		amazon_lazy_bids["/50970423/ffnhbdesktopfooter"] = ["div-gpt-ad-1554247110074-0","90","728"];
#   </script>
#   <script async="" src="https://securepubads.g.doubleclick.net/gpt/pubads_impl_2020120101.js">
#   </script>
#   <link as="script" href="https://adservice.google.com/adsid/integrator.js?domain=fastfoodnutrition.org" rel="preload"/>
#   <script src="https://adservice.google.com/adsid/integrator.js?domain=fastfoodnutrition.org" type="text/javascript">
#   </script>
#   <link href="https://cbf4bbebda29a9622eed4fb7615aece5.safeframe.googlesyndication.com/safeframe/1-0-37/html/container.html" rel="prefetch"/>
#  </head>
#  <body>
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-TTZ59GL&gt;m_auth=sgIpway-MsYi3RH24laOgQ&gt;m_preview=env-2&gt;m_cookies_win=x" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <div class="accent_gradient main_nav">
#    <div class="d-none d-md-block" id="topcontainer">
#     <div class="container">
#      <div class="row" id="toprow">
#       <div id="toplogodesk">
#        <a class="c_t" data-ctrack="header_logo" href="/" title="Fast Food Nutrition">
#         <img alt="Fast Food Nutrition" class="svg logo-svg" src="/images/logo.svg"/>
#        </a>
#       </div>
#       <div id="desk_leader_ad">
#        <div class="loaded refresh a_leader a_desk_leader" data-target="/50970423/ffn-hb-leader">
#         <div data-google-query-id="CMC42bi3tu0CFYTtyAodAG0G8g" id="div-gpt-ad-1487628416738-0">
#          <div id="google_ads_iframe_/50970423/ffn-hb-leader_0__container__" style="border: 0pt none;">
#           <iframe data-google-container-id="1" data-load-complete="true" frameborder="0" height="90" id="google_ads_iframe_/50970423/ffn-hb-leader_0" marginheight="0" marginwidth="0" name="google_ads_iframe_/50970423/ffn-hb-leader_0" sandbox="allow-forms allow-popups allow-popups-to-escape-sandbox allow-same-origin allow-scripts allow-top-navigation-by-user-activation" scrolling="no" srcdoc="" style="border: 0px; vertical-align: bottom;" title="3rd party ad content" width="728">
#           </iframe>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <nav class="navtop navbar-expand-md" role="navigation">
#     <div class="container">
#      <div class="navbar-brand d-block d-md-none">
#       <a class="c_t" data-ctrack="logo" href="/" style="display: block;
#     height: 35px;" title="Fast Food Nutrition">
#        <img alt="Fast Food Nutrition" class="logo-svg svg" src="/images/logo.svg"/>
#       </a>
#      </div>
#      <button class="navbar-toggler c_t" data-ctrack="hamburger-menu" data-target="#main-navigation" data-toggle="collapse" type="button">
#       <span class="sr-only">
#        Toggle navigation
#       </span>
#       <span class="icon-bar">
#       </span>
#       <span class="icon-bar">
#       </span>
#       <span class="icon-bar">
#       </span>
#      </button>
#      <div style="clear:both;">
#      </div>
#      <div class="collapse navbar-collapse" id="main-navigation">
#       <ul class="nav navbar-nav header_nav">
#        <li class="d-block d-sm-none">
#         <a class="c_t" data-ctrack="Header Home" href="/" title="Fast Food Nutrition Home">
#          Home
#         </a>
#        </li>
#        <li>
#         <a class="c_t" data-ctrack="Header Restaurants" href="/fast-food-restaurants" title="Fast Food Restaurants">
#          Restaurants
#         </a>
#        </li>
#        <li>
#         <a class="c_t" data-ctrack="Header Calculator" href="/fast-food-meal-calculator" title="Fast Food Nutrition Nutrition Calculator">
#          Nutrition Calculator
#         </a>
#        </li>
#        <li>
#         <a class="c_t" data-ctrack="Header New Items" href="/new-items" title="New Fast Food Items">
#          New Items
#         </a>
#        </li>
#        <li>
#         <a class="c_t" data-ctrack="Header News" href="/news" title="Fast Food Nutrition News">
#          News
#         </a>
#        </li>
#        <li class="d-block d-md-none">
#         <a class="c_t" data-ctrack="Header Glossary" href="/glossary" title="Nutrition Glossary">
#          Glossary
#         </a>
#        </li>
#        <li>
#         <a class="c_t" data-ctrack="Header Lessons" href="/lesson-plans" title="Fast Food Nutrition Lesson Plans">
#          Lesson Plans
#         </a>
#        </li>
#        <li class="d-block d-md-none">
#         <a class="c_t" data-ctrack="Header About Us" href="/about-us" title="About FastFoodNutrition.org">
#          About
#         </a>
#        </li>
#        <li class="d-block d-md-none">
#         <a href="/gsearchmobile" title="Search FastFoodNutrition.org">
#          Search
#         </a>
#        </li>
#        <li class="country_changer">
#         <a aria-expanded="true" aria-haspopup="true" class="dropdown-toggle c_t" data-ctrack="Header Switch Countries" data-toggle="dropdown" href="#" id="dropdownMenu1" title="Switch countries" type="button">
#          <img class="flag" src="/images/flags/usa.png"/>
#          <span class="caret">
#          </span>
#         </a>
#         <ul aria-labelledby="dropdownMenu1" class="dropdown-menu">
#          <li class="active">
#           <a class="c_t" data-ctrack="Country USA" href="#" title="USA Fast Food Nutrition">
#            <img src="/images/flags/usa.png"/>
#            USA
#           </a>
#          </li>
#          <li>
#           <a class="c_t" data-ctrack="Country Canada" href="/ca" title="Canada Fast Food Nutrition">
#            <img src="/images/flags/canada.png"/>
#            Canada
#           </a>
#          </li>
#         </ul>
#        </li>
#       </ul>
#       <div class="d-none d-sm-block">
#        <form action="/gsearch" id="cse-search-box">
#         <div id="desktopsearch">
#          <input name="cx" type="hidden" value="partner-pub-8872439879453765:6542173620"/>
#          <input name="cof" type="hidden" value="FORID:10"/>
#          <input name="ie" type="hidden" value="UTF-8"/>
#          <input name="q" placeholder="Custom Search" size="20" style='background: url("https://www.google.com/cse/static/images/1x/googlelogo_lightgrey_46x16dp.png") left center no-repeat rgb(255, 255, 255); text-indent: 48px;' type="text"/>
#         </div>
#         <input name="siteurl" type="hidden" value="fastfoodnutrition.org/subway"/>
#         <input name="ref" type="hidden" value=""/>
#         <input name="ss" type="hidden" value=""/>
#        </form>
#       </div>
#      </div>
#     </div>
#    </nav>
#    <div class="d-block d-md-none mobile_sub_nav">
#     <a class="c_t" data-ctrack="Mobile Header Restaurants" href="/fast-food-restaurants" title="Fast Food Restaurants">
#      Restaurants
#     </a>
#     <a class="c_t" data-ctrack="Mobile Header Calculator" href="/fast-food-meal-calculator" title="Fast Food Nutrition Nutrition Calculator">
#      Calculator
#     </a>
#     <a class="c_t" data-ctrack="Mobile Header News" href="/news" title="Fast Food Nutrition News">
#      News
#     </a>
#    </div>
#   </div>
#   <div class="d-block d-md-none" style="height:83px">
#   </div>
#   <div class="rest_links_outside container">
#    <div style="background:#008938; overflow:hidden; padding:0;">
#     <div style="">
#      <div class="rest_links_name" style="background:#008938;">
#       <h3>
#        Subway
#       </h3>
#      </div>
#      <div class="rest_links_container scroll_container">
#       <ul class="rest_links">
#        <li class="active">
#         <a class="tabs" href="/subway" title="Subway Nutrition">
#          Nutrition
#         </a>
#        </li>
#        <li>
#         <a class="tabs" href="/subway/calculator" title="Subway Nutrition Calculator">
#          Calculator
#         </a>
#        </li>
#        <li>
#         <a class="tabs" href="/subway/weight-watchers" title="Subway Weight Watchers Points">
#          Weight Watchers
#         </a>
#        </li>
#        <li>
#         <a class="tabs" href="/subway/popular" title="Popular Items at Subway">
#          Popular Items
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="container main_container">
#    <div style="position: relative;">
#     <div class="d-none d-lg-block vertical_margins left_column">
#      <div class="side_card_head">
#       Restaurants
#      </div>
#      <div style="clear:both;">
#      </div>
#      <ul class="list divider restaurant_list">
#       <li>
#        <a class="c_t" data-ctrack="full restaurant list" href="/arbys" title="Arby's Nutrition Facts">
#         Arby's
#        </a>
#       </li>
#       <li>
#        <a class="c_t" data-ctrack="full restaurant list" href="/baskin-robbins" title="Baskin-Robbins Nutrition Facts">
#         Baskin-Robbins
#        </a>
#       </li>
#       <li>
#        <a class="c_t" data-ctrack="full restaurant list" href="/blimpie" title="Blimpie Nutrition Facts">
#         Blimpie
#        </a>
#       </li>
#       <li>
#        <a class="c_t" data-ctrack="full restaurant list" href="/bojangles" title="Bojangles Nutrition Facts">
#         Bojangles
#        </a>
#       </li>
#       <li>
#        <a class="c_t" data-ctrack="full restaurant list" href="/boston-market" title="Boston Market Nutrition Facts">
#         Boston Market
#        </a>
#       </li>
#       <li>
#        <a class="c_t" data-ctrack="full restaurant list" href="/buffalo-wild-wings" title="Buffalo Wild Wings Nutrition Facts">
#         Buffalo Wild Wings
#        </a>
#       </li>
#       <li>
#        <a class="c_t" data-ctrack="full restaurant list" href="/burger-king" title="Burger King Nutrition Facts">
#         Burger King
#        </a>
#       </li>
#       <li>
#        <a class="c_t" data-ctrack="full restaurant list" href="/carls-jr" title="Carl's Jr Nutrition Facts">
#         Carl's Jr
#        </a>
#       </li>
#       <li>
#        <a class="c_t" data-ctrack="full restaurant list" href="/chick-fil-a" title="Chick-fil-A Nutrition Facts">
#         Chick-fil-A
#        </a>
#       </li>
#       <li>
#        <a class="c_t" data-ctrack="full restaurant list" href="/chipotle" title="Chipotle Nutrition Facts">
#         Chipotle
#        </a>
#       </li>
#       <li>
#        <a class="c_t" data-ctrack="full restaurant list" href="/culvers" title="Culvers Nutrition Facts">
#         Culvers
#        </a>
#       </li>
#       <li>
#        <a class="c_t" data-ctrack="full restaurant list" href="/dairy-queen" title="Dairy Queen Nutrition Facts">
#         Dairy Queen
#        </a>
#       </li>
#       <li>
#        <a class="c_t" data-ctrack="full restaurant list" href="/del-taco" title="Del Taco Nutrition Facts">
#         Del Taco
#        </a>
#       </li>
#       <li>
#        <a class="c_t" data-ctrack="full restaurant list" href="/dominos-pizza" title="Domino's Pizza Nutrition Facts">
#         Domino's Pizza
#        </a>
#       </li>
#       <li>
#        <a class="c_t" data-ctrack="full restaurant list" href="/dunkin-donuts" title="Dunkin Donuts Nutrition Facts">
#         Dunkin Donuts
#        </a>
#       </li>
#       <li>
#        <a class="c_t" data-ctrack="full restaurant list" href="/five-guys" title="Five Guys Nutrition Facts">
#         Five Guys
#        </a>
#       </li>
#       <li>
#        <a class="c_t" data-ctrack="full restaurant list" href="/godfathers-pizza" title="Godfather's Pizza Nutrition Facts">
#         Godfather's Pizza
#        </a>
#       </li>
#       <li>
#        <a class="c_t" data-ctrack="full restaurant list" href="/hardees" title="Hardee's Nutrition Facts">
#         Hardee's
#        </a>
#       </li>
#       <li>
#        <a class="c_t" data-ctrack="full restaurant list" href="/in-n-out-burger" title="In-N-Out Burger Nutrition Facts">
#         In-N-Out Burger
#        </a>
#       </li>
#       <li>
#        <a class="c_t" data-ctrack="full restaurant list" href="/jack-in-the-box" title="Jack in the Box Nutrition Facts">
#         Jack in the Box
#        </a>
#       </li>
#       <li>
#        <a class="c_t" data-ctrack="full restaurant list" href="/jimmy-johns" title="Jimmy Johns Nutrition Facts">
#         Jimmy Johns
#        </a>
#       </li>
#       <li>
#        <a class="c_t" data-ctrack="full restaurant list" href="/kfc" title="KFC Nutrition Facts">
#         KFC
#        </a>
#       </li>
#       <li>
#        <a class="c_t" data-ctrack="full restaurant list" href="/little-caesars" title="Little Caesars Nutrition Facts">
#         Little Caesars
#        </a>
#       </li>
#       <li>
#        <a class="c_t" data-ctrack="full restaurant list" href="/long-john-silvers" title="Long John Silver's Nutrition Facts">
#         Long John Silver's
#        </a>
#       </li>
#       <li>
#        <a class="c_t" data-ctrack="full restaurant list" href="/mcdonalds" title="McDonald's Nutrition Facts">
#         McDonald's
#        </a>
#       </li>
#       <li>
#        <a class="c_t" data-ctrack="full restaurant list" href="/olive-garden" title="Olive Garden Nutrition Facts">
#         Olive Garden
#        </a>
#       </li>
#       <li>
#        <a class="c_t" data-ctrack="full restaurant list" href="/panda-express" title="Panda Express Nutrition Facts">
#         Panda Express
#        </a>
#       </li>
#       <li>
#        <a class="c_t" data-ctrack="full restaurant list" href="/panera-bread" title="Panera Nutrition Facts">
#         Panera
#        </a>
#       </li>
#       <li>
#        <a class="c_t" data-ctrack="full restaurant list" href="/papa-johns" title="Papa John's Nutrition Facts">
#         Papa John's
#        </a>
#       </li>
#       <li>
#        <a class="c_t" data-ctrack="full restaurant list" href="/pizza-hut" title="Pizza Hut Nutrition Facts">
#         Pizza Hut
#        </a>
#       </li>
#       <li>
#        <a class="c_t" data-ctrack="full restaurant list" href="/popeyes" title="Popeyes Nutrition Facts">
#         Popeyes
#        </a>
#       </li>
#       <li>
#        <a class="c_t" data-ctrack="full restaurant list" href="/quiznos" title="Quiznos Nutrition Facts">
#         Quiznos
#        </a>
#       </li>
#       <li>
#        <a class="c_t" data-ctrack="full restaurant list" href="/red-lobster" title="Red Lobster Nutrition Facts">
#         Red Lobster
#        </a>
#       </li>
#       <li>
#        <a class="c_t" data-ctrack="full restaurant list" href="/smashburger" title="Smashburger Nutrition Facts">
#         Smashburger
#        </a>
#       </li>
#       <li>
#        <a class="c_t" data-ctrack="full restaurant list" href="/sonic" title="Sonic Nutrition Facts">
#         Sonic
#        </a>
#       </li>
#       <li>
#        <a class="c_t" data-ctrack="full restaurant list" href="/starbucks" title="Starbucks Nutrition Facts">
#         Starbucks
#        </a>
#       </li>
#       <li>
#        <a class="c_t" data-ctrack="full restaurant list" href="/subway" title="Subway Nutrition Facts">
#         Subway
#        </a>
#       </li>
#       <li>
#        <a class="c_t" data-ctrack="full restaurant list" href="/taco-bell" title="Taco Bell Nutrition Facts">
#         Taco Bell
#        </a>
#       </li>
#       <li>
#        <a class="c_t" data-ctrack="full restaurant list" href="/taco-johns" title="Taco John's Nutrition Facts">
#         Taco John's
#        </a>
#       </li>
#       <li>
#        <a class="c_t" data-ctrack="full restaurant list" href="/wendys" title="Wendy's Nutrition Facts">
#         Wendy's
#        </a>
#       </li>
#       <li>
#        <a class="c_t" data-ctrack="full restaurant list" href="/whataburger" title="Whataburger Nutrition Facts">
#         Whataburger
#        </a>
#       </li>
#       <li>
#        <a class="c_t" data-ctrack="full restaurant list" href="/zaxbys" title="Zaxby's Nutrition Facts">
#         Zaxby's
#        </a>
#       </li>
#      </ul>
#     </div>
#     <div id="contentarea">
#      <div class="rest_page">
#       <div class="ratingbox topbox">
#        <nav class="scroll_container bcrumb">
#         <div>
#          <a class="c_t breadcrumb-item" data-ctrack="breadcrumb" href="/fast-food-restaurants" title="Fast Food Restaurants">
#           <span data-ctrack="breadcrumb">
#            Restaurants
#           </span>
#          </a>
#          <span class="breadcrumb-item d-sm-inline" style="text-decoration:none;">
#           Subway
#          </span>
#         </div>
#        </nav>
#        <h1>
#         Subway Nutrition Facts
#        </h1>
#        <p>
#         <img alt="Subway Nutrition Facts" class="logo_float" src="/logos/subway.jpg"/>
#         Nutrition facts for the full Subway Sandwiches menu. Select any item to view the complete nutritional information including calories, carbs, sodium and Weight Watchers points. You can also use our calorie filter to find the Subway menu item that best fits your diet.
#        </p>
#        <button class="btn btn-default toggle_modal btn-sm c_t" data-ctrack="share-open-modal" data-target="share_modal">
#         <span class="icon-share2">
#         </span>
#         Share
#        </button>
#        <p style="font-size:13px;">
#         <span class="healthy_heart icon-heart">
#         </span>
#         = Voted a healthy and tasty option.
#         <a href="/healthy-tasty-options" style="display:inline-block;padding:2px;text-decoration:none; font-size:15px">
#          <span class="icon-question">
#          </span>
#          <span class="sr-only">
#           Learn how healthy and tasty options determined.
#          </span>
#         </a>
#        </p>
#        <span class="small_text">
#         Updated: 10/23/2020
#        </span>
#       </div>
#       <h2 class="mobile_padding">
#        Subway Menu Nutrition
#       </h2>
#       <div class="mobile_padding vertical_margins">
#        <button class="btn btn-primary hide_me" data-target=".filters" data-toggle="collapse" title="Filter the Subway menu">
#         ▼ Filter Menu
#        </button>
#       </div>
#       <div class="ratingbox vertical_margins collapse filters">
#        <h3>
#         Filter the Subway menu
#        </h3>
#        <div class="row">
#         <div class="col-12 col-sm-6">
#          <div class="filterheader">
#           Show items that are:
#          </div>
#          <div class="btn-group btn-group-sm" role="group">
#           <a class="btn btn-primary disabled" href="#" title="Subway nutrition facts">
#            Available
#           </a>
#           <a class="btn btn-default" href="/subway/discontinued" title="Subway discontinued nutrition facts">
#            Discontinued
#           </a>
#          </div>
#         </div>
#         <div class="col-12 col-sm-6">
#          <div>
#           <div class="filterheader">
#            Filter by Calories
#           </div>
#           <div>
#            <div class="slider noUi-extended noUi-target noUi-ltr noUi-horizontal noUi-connect" id="calorieslider">
#             <div class="noUi-base">
#              <div class="noUi-origin noUi-background noUi-stacking" style="left: 100%;">
#               <div class="noUi-handle noUi-handle-lower">
#               </div>
#              </div>
#             </div>
#            </div>
#            ≤
#            <span id="calorieoutput">
#             1000
#            </span>
#            calories
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <form action="" id="filter_form">
#        <div class="mobile_padding input-group" style="margin-bottom:15px;">
#         <label class="sr-only" for="filter_text">
#          Search the menu
#         </label>
#         <input class="form-control" id="filter_text" placeholder="Search Menu" type="text"/>
#         <div class="input-group-append">
#          <button aria-label="Clear" class="btn btn-default" type="button">
#           <span class="icon-search">
#           </span>
#          </button>
#         </div>
#        </div>
#       </form>
#       <div class="not-found">
#       </div>
#       <div class="category">
#        <a class="toggle_category toggle_div" data-target=".category_19" data-toggle="collapse" data-toggletarget="category_19" href="#" id="subway-sandwiches" title="Subway Subway Sandwiches Nutrition Facts">
#         <div class="icon_category_19 rotating_icon rotated" style="float:right; height:25px;">
#          <span class="icon-circle-down">
#          </span>
#         </div>
#         <h2>
#          Subway Sandwiches
#         </h2>
#         <div>
#          <span class="small_text item_count item_count_19">
#           38 items
#          </span>
#         </div>
#        </a>
#        <div class="categories in category_19 collapse show" style="margin-bottom:15px;">
#         <ul class="list rest_item_list">
#          <li class="filter_target" data-calories="450" title='6" Chipotle Chicken and Cheese'>
#           <div class="19">
#            <a class="listlink item_link active_item_link" href="/subway/6-chipotle-chicken-and-cheese" title='Subway 6" Chipotle Chicken and Cheese Nutrition Facts'>
#             6" Chipotle Chicken and Cheese
#             <div class="nutrition_button">
#              <button class="btn btn-default btn-sm">
#               Nutrition Facts
#              </button>
#              450 calories
#             </div>
#            </a>
#           </div>
#          </li>
#          <li class="filter_target" data-calories="340" title="B.L.T.">
#           <div class="19">
#            <a class="listlink item_link active_item_link" href="/subway/blt" title="Subway B.L.T. Nutrition Facts">
#             B.L.T.
#             <span class="icon-heart healthy_heart">
#             </span>
#             <div class="nutrition_button">
#              <button class="btn btn-default btn-sm">
#               Nutrition Facts
#              </button>
#              340-640 calories
#             </div>
#            </a>
#           </div>
#          </li>
#          <li class="filter_target" data-calories="580" title="BBQ Rib Sandwich">
#           <div class="19">
#            <a class="listlink item_link active_item_link" href="/subway/bbq-rib-sandwich" title="Subway BBQ Rib Sandwich Nutrition Facts">
#             BBQ Rib Sandwich
#             <div class="nutrition_button">
#              <button class="btn btn-default btn-sm">
#               Nutrition Facts
#              </button>
#              580-1160 calories
#             </div>
#            </a>
#           </div>
#          </li>
#          <li class="filter_target" data-calories="580" title="Big Hot Pastrami">
#           <div class="19">
#            <a class="listlink item_link active_item_link" href="/subway/big-hot-pastrami" title="Subway Big Hot Pastrami Nutrition Facts">
#             Big Hot Pastrami
#             <div class="nutrition_button">
#              <button class="btn btn-default btn-sm">
#               Nutrition Facts
#              </button>
#              580-1160 calories
#             </div>
#            </a>
#           </div>
#          </li>
# ...
#             <img alt="Burger King French Fries" class="lozad" data-src="/item-photos/200x156/1470_s.jpg" src="/images/placeholder.png" style="width: 100%;"/>
#             <noscript>
#              <img alt="Burger King French Fries" src="/item-photos/200x156/1470_s.jpg"/>
#             </noscript>
#            </div>
#            <div class="col-9" data-ctrack="Popular Item" style="padding-left:0;">
#             Burger King French Fries
#            </div>
#           </a>
#          </li>
#          <li>
#           <a class="c_t" data-ctrack="Popular Item" href="/chick-fil-a/grilled-chicken-nuggets" style="display:flex;height:50px;overflow:hidden;padding:10px 0;" title="Chick-fil-A Grilled Chicken Nuggets Nutrition Facts">
#            <div class="col-3" data-ctrack="Popular Item">
#             <img alt="Chick-fil-A Grilled Chicken Nuggets" class="lozad" data-src="/item-photos/200x147/6308_s.jpg" src="/images/placeholder.png" style="width: 100%;"/>
#             <noscript>
#              <img alt="Chick-fil-A Grilled Chicken Nuggets" src="/item-photos/200x147/6308_s.jpg"/>
#             </noscript>
#            </div>
#            <div class="col-9" data-ctrack="Popular Item" style="padding-left:0;">
#             Chick-fil-A Grilled Chicken Nuggets
#            </div>
#           </a>
#          </li>
#          <li>
#           <a class="c_t" data-ctrack="Popular Item" href="/wendys/chili" style="display:flex;height:50px;overflow:hidden;padding:10px 0;" title="Wendy's Chili Nutrition Facts">
#            <div class="col-3" data-ctrack="Popular Item">
#             <img alt="Wendy's Chili" class="lozad" data-src="/item-photos/200x200/500_s.jpg" src="/images/placeholder.png" style="width: 100%;"/>
#             <noscript>
#              <img alt="Wendy's Chili" src="/item-photos/200x200/500_s.jpg"/>
#             </noscript>
#            </div>
#            <div class="col-9" data-ctrack="Popular Item" style="padding-left:0;">
#             Wendy's Chili
#            </div>
#           </a>
#          </li>
#          <li>
#           <a class="c_t" data-ctrack="Popular Item" href="/boston-market/turkey-breast" style="display:flex;height:50px;overflow:hidden;padding:10px 0;" title="Boston Market Turkey Breast Nutrition Facts">
#            <div class="col-3" data-ctrack="Popular Item">
#             <img alt="Boston Market Turkey Breast" class="lozad" data-src="/item-photos/200x114/649_s.jpg" src="/images/placeholder.png" style="width: 100%;"/>
#             <noscript>
#              <img alt="Boston Market Turkey Breast" src="/item-photos/200x114/649_s.jpg"/>
#             </noscript>
#            </div>
#            <div class="col-9" data-ctrack="Popular Item" style="padding-left:0;">
#             Boston Market Turkey Breast
#            </div>
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#       <div class="vertical_margins">
#        <div class="not_loaded refresh a_rect" data-target="/50970423/ffn-hb-rect-3">
#         <div id="div-gpt-ad-1487628416738-4">
#         </div>
#        </div>
#       </div>
#       <div class="vertical_margins">
#        <div class="side_card_head">
#         Recently Added
#        </div>
#        <div class="boxcontent divider">
#         <ul class="list recent_item_list">
#          <li>
#           <a class="c_t" data-ctrack="New Items" href="/jimmy-johns/smokin-kickin-chicken" title="Jimmy Johns Smokin' Kickin' Chicken Nutrition Facts">
#            Jimmy Johns Smokin' Kickin' Chicken
#           </a>
#          </li>
#          <li>
#           <a class="c_t" data-ctrack="New Items" href="/chick-fil-a/chicken-tortilla-soup" title="Chick-fil-A Chicken Tortilla Soup Nutrition Facts">
#            Chick-fil-A Chicken Tortilla Soup
#           </a>
#          </li>
#          <li>
#           <a class="c_t" data-ctrack="New Items" href="/chick-fil-a/peppermint-chocolate-chip-milkshake" title="Chick-fil-A Peppermint Chocolate Chip Milkshake Nutrition Facts">
#            Chick-fil-A Peppermint Chocolate Chip Milkshake
#           </a>
#          </li>
#          <li>
#           <a class="c_t" data-ctrack="New Items" href="/pizza-hut/hand-tossed-great-beyond-pizza" title="Pizza Hut Hand-Tossed Great Beyond Pizza Nutrition Facts">
#            Pizza Hut Hand-Tossed Great Beyond Pizza
#           </a>
#          </li>
#          <li>
#           <a class="c_t" data-ctrack="New Items" href="/pizza-hut/hand-tossed-beyond-italian-sausage-pizza" title="Pizza Hut Hand-Tossed Beyond Italian Sausage Pizza Nutrition Facts">
#            Pizza Hut Hand-Tossed Beyond Italian Sausage Pizza
#           </a>
#          </li>
#          <li>
#           <a class="c_t" data-ctrack="New Items" href="/pizza-hut/the-great-beyond-pan-pizza" title="Pizza Hut The Great Beyond Pan Pizza Nutrition Facts">
#            Pizza Hut The Great Beyond Pan Pizza
#           </a>
#          </li>
#          <li>
#           <a class="c_t" data-ctrack="New Items" href="/pizza-hut/beyond-italian-sausage-pan-pizza" title="Pizza Hut Beyond Italian Sausage Pan Pizza Nutrition Facts">
#            Pizza Hut Beyond Italian Sausage Pan Pizza
#           </a>
#          </li>
#          <li>
#           <a class="c_t" data-ctrack="New Items" href="/starbucks/snowman-cake-pop" title="Starbucks Snowman Cake Pop Nutrition Facts">
#            Starbucks Snowman Cake Pop
#           </a>
#          </li>
#          <li>
#           <a class="c_t" data-ctrack="New Items" href="/starbucks/snowman-cookie" title="Starbucks Snowman Cookie Nutrition Facts">
#            Starbucks Snowman Cookie
#           </a>
#          </li>
#          <li>
#           <a class="c_t" data-ctrack="New Items" href="/starbucks/cranberry-bliss-bar" title="Starbucks Cranberry Bliss Bar Nutrition Facts">
#            Starbucks Cranberry Bliss Bar
#           </a>
#          </li>
#          <li>
#           <a class="c_t" data-ctrack="New Items" href="/starbucks/sugar-plum-cheese-danish" title="Starbucks Sugar Plum Cheese Danish Nutrition Facts">
#            Starbucks Sugar Plum Cheese Danish
#           </a>
#          </li>
#          <li>
#           <a class="c_t" data-ctrack="New Items" href="/starbucks/cranberry-orange-scone" title="Starbucks Cranberry Orange Scone Nutrition Facts">
#            Starbucks Cranberry Orange Scone
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#      </div>
#      <div class="sticky_a_container" style="height: 13466px; position: relative;">
#       <div style="position: sticky;height:20px;top:0;">
#        <div class="not_loaded refresh a_rect" data-target="/50970423/ffn-hb-rect-4">
#         <div id="div-gpt-ad-1600282375298-0">
#         </div>
#        </div>
#        <div class="not_loaded refresh a_rect" data-target="/50970423/ffn-hb-rect-ex">
#         <div id="div-gpt-ad-1600282464548-0">
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div style="clear:both;">
#    </div>
#   </div>
#   <div class="footer_container footer_nav">
#    <div class="mobile_padding">
#     <div style="overflow:hidden;">
#      <div class="follow-us">
#       <a class="c_t" data-ctrack="Footer Facebook" href="https://www.facebook.com/FastFoodNutrition" title="Fast Food Nutrition on Facebook">
#        <span class="icon-facebook">
#        </span>
#       </a>
#       <a class="c_t" data-ctrack="Footer Pinterest" href="http://pinterest.com/ffnutrition/" title="Fast Food Nutrition on Pinterest">
#        <span class="icon-pinterest">
#        </span>
#       </a>
#       <a class="c_t" data-ctrack="Footer Twitter" href="http://twitter.com/F_F_Nutrition" title="Fast Food Nutrition on Twitter">
#        <span class="icon-twitter">
#        </span>
#       </a>
#      </div>
#     </div>
#     <div id="copyright">
#      <br/>
#      <a class="c_t" data-ctrack="Footer Home" href="/" title="Fast Food Nutrition Home">
#       Home
#      </a>
#      |
#      <a class="c_t" data-ctrack="Footer Restaurants" href="/fast-food-restaurants" title="Fast Food Restaurants">
#       Restaurants
#      </a>
#      |
#      <a class="c_t" data-ctrack="Footer Calculator" href="/fast-food-meal-calculator" title="Fast Food Nutrition Nutrition Calculator">
#       Nutrition Calculator
#      </a>
#      |
#      <a class="c_t" data-ctrack="Footer News" href="/news" title="Fast Food Nutrition News">
#       News
#      </a>
#      |
#      <a class="c_t" data-ctrack="Footer Glossary" href="/glossary" title="Nutrition Glossary">
#       Nutrition Glossary
#      </a>
#      |
#      <a class="c_t" data-ctrack="Footer Lesson Plans " href="/lesson-plans" title="Fast Food Nutrition Lesson Plans">
#       Lesson Plans for Teachers
#      </a>
#      |
#      <a class="c_t" data-ctrack="Footer About Us" href="/about-us" title="About FastFoodNutrition.org">
#       About Us
#      </a>
#      |
#      <a class="c_t" data-ctrack="Footer Healthy Tasty" href="/healthy-tasty-options" title="Healthy, good tasting fast food options">
#       Healthy Tasty Items
#      </a>
#      |
#      <a class="c_t" data-ctrack="Footer Mobile" href="/mobile" title="Fast Food Nutrition On Your Phone">
#       Mobile Nutrition Facts
#      </a>
#      <br/>
#      <br/>
#      Warning: For medical or nutritional advice, do not rely on this site. Please consult a dietician or medical doctor instead.
#      <br/>
#      <br/>
#      All Copyrighted and Trademarked information is property of the respective owners.
#      <br/>
#      <br/>
#      <a class="c_t" data-ctrack="Footer Links" href="/links">
#       Links
#      </a>
#      |
#      <a class="c_t" data-ctrack="Footer Privacy" href="/privacy">
#       Privacy Policy
#      </a>
#     </div>
#     <div style="height: 52px;width: 100%;">
#     </div>
#    </div>
#   </div>
#   <div class="notice_container">
#    <div class="notice_message">
#    </div>
#   </div>
#   <div class="sticky_footer desktop" style="position:fixed;z-index:9999999;bottom:0;pointer-events: none; margin: 0;left:0;right:0;">
#    <div style="pointer-events:auto; margin:0 auto;width:728px;position:relative;">
#     <a class="toggle-element" data-target="sticky_footer" href="#" style="display:block;position:absolute;margin:0;padding:0;border:0; top: -15px;right:0px;background:rgba(0,0,0,.4);height:15px; width: 15px;overflow:hidden;color:#fff;font-size:12px; line-height:13px;text-align:center;">
#      x
#     </a>
#     <div class="loaded refresh a_leader" data-target="/50970423/ffn-hb-desktop-footer">
#      <div data-google-query-id="CJ-92bi3tu0CFYTtyAodAG0G8g" id="div-gpt-ad-1554247110074-0">
#       <div id="google_ads_iframe_/50970423/ffn-hb-desktop-footer_0__container__" style="border: 0pt none;">
#        <iframe data-google-container-id="4" data-load-complete="true" frameborder="0" height="90" id="google_ads_iframe_/50970423/ffn-hb-desktop-footer_0" marginheight="0" marginwidth="0" name="google_ads_iframe_/50970423/ffn-hb-desktop-footer_0" sandbox="allow-forms allow-popups allow-popups-to-escape-sandbox allow-same-origin allow-scripts allow-top-navigation-by-user-activation" scrolling="no" srcdoc="" style="border: 0px; vertical-align: bottom;" title="3rd party ad content" width="728">
#        </iframe>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <script type="application/ld+json">
#    {
# 		  "@context": "http://schema.org",
# 		   "@type": "Restaurant", "name": "Subway", "image": "https://fastfoodnutrition.org/logos/subway.jpg", "servesCuisine": "Fast Food", "menu":{ "@type":"Menu", "name":"Subway Menu", "hasMenuSection":[ { "@type":"MenuSection", "name":"Subway Sandwiches", "description":"Subway Sandwiches from Subway.", "image":[ "https://fastfoodnutrition.org/logos/subway.jpg" ], "hasMenuItem":[ { "@type":"MenuItem", "name":"6&quot; Chipotle Chicken and Cheese", "mainEntityOfPage":"https://fastfoodnutrition.org/subway/6-chipotle-chicken-and-cheese", "nutrition": { "@type": "NutritionInformation", "calories": "450 calories" } } , { "@type":"MenuItem", "name":"B.L.T.", "mainEntityOfPage":"https://fastfoodnutrition.org/subway/blt", "nutrition": { "@type": "NutritionInformation", "calories": "340 calories" } } , { "@type":"MenuItem", "name":"BBQ Rib Sandwich", "mainEntityOfPage":"https://fastfoodnutrition.org/subway/bbq-rib-sandwich", "nutrition": { "@type": "NutritionInformation", "calories": "580 calories" } } , { "@type":"MenuItem", "name":"Big Hot Pastrami", "mainEntityOfPage":"https://fastfoodnutrition.org/subway/big-hot-pastrami", "nutrition": { "@type": "NutritionInformation", "calories": "580 calories" } } , { "@type":"MenuItem", "name":"Black Forest Ham", "mainEntityOfPage":"https://fastfoodnutrition.org/subway/black-forest-ham", "nutrition": { "@type": "NutritionInformation", "calories": "180 calories" } } , { "@type":"MenuItem", "name":"Buffalo Chicken Sandwich", "mainEntityOfPage":"https://fastfoodnutrition.org/subway/6-buffalo-chicken", "nutrition": { "@type": "NutritionInformation", "calories": "340 calories" } } , { "@type":"MenuItem", "name":"Chicken & Bacon Ranch Melt", "mainEntityOfPage":"https://fastfoodnutrition.org/subway/chicken-bacon-ranch-melt", "nutrition": { "@type": "NutritionInformation", "calories": "570 calories" } } , { "@type":"MenuItem", "name":"Chicken Cordon Bleu Melt", "mainEntityOfPage":"https://fastfoodnutrition.org/subway/6-chicken-cordon-bleu-melt", "nutrition": { "@type": "NutritionInformation", "calories": "410 calories" } } , { "@type":"MenuItem", "name":"Chicken Mango Curry Sandwich", "mainEntityOfPage":"https://fastfoodnutrition.org/subway/chicken-mango-curry-sandwich", "nutrition": { "@type": "NutritionInformation", "calories": "330 calories" } } , { "@type":"MenuItem", "name":"Chicken Pizziola Melt", "mainEntityOfPage":"https://fastfoodnutrition.org/subway/chicken-pizziola-melt", "nutrition": { "@type": "NutritionInformation", "calories": "460 calories" } } , { "@type":"MenuItem", "name":"Chicken Tikka Sandwich", "mainEntityOfPage":"https://fastfoodnutrition.org/subway/chicken-tikka-sandwich", "nutrition": { "@type": "NutritionInformation", "calories": "290 calories" } } , { "@type":"MenuItem", "name":"Chicken Vindaloo Sandwich", "mainEntityOfPage":"https://fastfoodnutrition.org/subway/chicken-vindaloo-sandwich", "nutrition": { "@type": "NutritionInformation", "calories": "340 calories" } } , { "@type":"MenuItem", "name":"Cold Cut Combo", "mainEntityOfPage":"https://fastfoodnutrition.org/subway/cold-cut-combo", "nutrition": { "@type": "NutritionInformation", "calories": "370 calories" } } , { "@type":"MenuItem", "name":"Genoa Salami Sandwich", "mainEntityOfPage":"https://fastfoodnutrition.org/subway/genoa-salami-sandwich", "nutrition": { "@type": "NutritionInformation", "calories": "430 calories" } } , { "@type":"MenuItem", "name":"Ham & Jack Slider", "mainEntityOfPage":"https://fastfoodnutrition.org/subway/ham-jack-slider", "nutrition": { "@type": "NutritionInformation", "calories": "150 calories" } } , { "@type":"MenuItem", "name":"Italian B.M.T.", "mainEntityOfPage":"https://fastfoodnutrition.org/subway/italian-bmt", "nutrition": { "@type": "NutritionInformation", "calories": "410 calories" } } , { "@type":"MenuItem", "name":"Italian Spice Slider", "mainEntityOfPage":"https://fastfoodnutrition.org/subway/italian-spice-slider", "nutrition": { "@type": "NutritionInformation", "calories": "230 calories" ...
#
# 		}
#   </script>
#   <script type="text/javascript">
#    if (!('IntersectionObserver' in window)) {
#     var script = document.createElement("script");
#     script.src = "https://cdn.rawgit.com/w3c/IntersectionObserver/master/polyfill/intersection-observer.js";
#     document.getElementsByTagName('head')[0].appendChild(script);
# }
#   </script>
#   <script src="/js/cache/1.0.69/jquery--ads--jquery.nouislider--ffn--popper--bootstrap-index--bootstrap-util--bootstrap-collapse--bootstrap-button--bootstrap-dropdown.js" type="text/javascript">
#   </script>
#   <link href="https://fonts.googleapis.com/css?family=Open+Sans:300,400,700&amp;display=swap" rel="stylesheet"/>
#   <script data-cookieconsent="preferences" src="//www.google.com/coop/cse/brand?form=cse-search-box&amp;lang=en" type="text/javascript">
#   </script>
#   <iframe src="https://s.amazon-adsystem.com/iu3?cm3ppd=1&amp;d=dtb-pub&amp;csif=t&amp;dl=n-index_pm-db5_rbd_n-vmg_r1u_dm_cnv_sovrn_dmx" style="display: none;">
#   </iframe>
#  </body>
# </html>

# %%
#html object here
html = browser.html

#html
#boutifulsoup
soup = BeautifulSoup(html, 'html.parser')

# %%
#getting anchor tags 
subwa_sandwich = soup.find('div', class_ = 'categories in category_19 collapse show')
subwa_sandwich = subwa_sandwich.ul
subway_links = []
for a in subwa_sandwich.find_all('a', href=True): 
        subway_links.append(a['href'])
print('subway_sandwich:','--')
print('\n--------------------\n')
print(subway_links)
print('\n--------------------\n')
# Out:
# subway_sandwich: --
#
# --------------------
#
# ['/subway/6-chipotle-chicken-and-cheese', '/subway/blt', '/subway/bbq-rib-sandwich', '/subway/big-hot-pastrami', '/subway/black-forest-ham', '/subway/6-buffalo-chicken', '/subway/chicken-bacon-ranch-melt', '/subway/6-chicken-cordon-bleu-melt', '/subway/chicken-mango-curry-sandwich', '/subway/chicken-pizziola-melt', '/subway/chicken-tikka-sandwich', '/subway/chicken-vindaloo-sandwich', '/subway/cold-cut-combo', '/subway/genoa-salami-sandwich', '/subway/ham-jack-slider', '/subway/italian-bmt', '/subway/italian-spice-slider', '/subway/little-cheesesteak-slider', '/subway/little-turkey-slider', '/subway/meatball-marinara', '/subway/oven-roasted-chicken', '/subway/paneer-tikka-sandwich', '/subway/roast-beef', '/subway/rotisserie-style-chicken', '/subway/southwest-chicken-club-sandwich', '/subway/spicy-italian', '/subway/steak-and-cheese', '/subway/subway-club', '/subway/subway-melt-includes-cheese', '/subway/subway-seafood-sensation', '/subway/sweet-onion-chicken-teriyaki', '/subway/tuna', '/subway/turkey-bacon-avocado', '/subway/turkey-breast', '/subway/turkey-breast-ham', '/subway/turkey-italiano-melt-with-provolone', '/subway/veggie-delite', '/subway/veggie-patty']
#
# --------------------

# %%
#Subway 6 
#Subway 6' chipotle chicken and cheese

#browser.visit('https://fastfoodnutrition.org/subway/6-chipotle-chicken-and-cheese')
#html object here
#html = browser.html

#soup object: specific subway
#sub_s = BeautifulSoup(html, 'html.parser')
#data_subway = pd.read_html(browser.html)

#subway_df = data_subway[0]
#x_df = data_subway[0]
#x_df

# %%
#size 6 

fastfood_link = 'https://fastfoodnutrition.org'
food_links = [ ]

# %%
for link in subway_links:
    print('\n--------\n')
    print(fastfood_link + link )
    food_links.append(fastfood_link + link + '/6')
# Out:
# --------
#
# https://fastfoodnutrition.org/subway/6-chipotle-chicken-and-cheese
#
# --------
#
# https://fastfoodnutrition.org/subway/blt
#
# --------
#
# https://fastfoodnutrition.org/subway/bbq-rib-sandwich
#
# --------
#
# https://fastfoodnutrition.org/subway/big-hot-pastrami
#
# --------
#
# https://fastfoodnutrition.org/subway/black-forest-ham
#
# --------
#
# https://fastfoodnutrition.org/subway/6-buffalo-chicken
#
# --------
#
# https://fastfoodnutrition.org/subway/chicken-bacon-ranch-melt
#
# --------
#
# https://fastfoodnutrition.org/subway/6-chicken-cordon-bleu-melt
#
# --------
#
# https://fastfoodnutrition.org/subway/chicken-mango-curry-sandwich
#
# --------
#
# https://fastfoodnutrition.org/subway/chicken-pizziola-melt
#
# --------
#
# https://fastfoodnutrition.org/subway/chicken-tikka-sandwich
#
# --------
#
# https://fastfoodnutrition.org/subway/chicken-vindaloo-sandwich
#
# --------
#
# https://fastfoodnutrition.org/subway/cold-cut-combo
#
# --------
#
# https://fastfoodnutrition.org/subway/genoa-salami-sandwich
#
# --------
#
# https://fastfoodnutrition.org/subway/ham-jack-slider
#
# --------
#
# https://fastfoodnutrition.org/subway/italian-bmt
#
# --------
#
# https://fastfoodnutrition.org/subway/italian-spice-slider
#
# --------
#
# https://fastfoodnutrition.org/subway/little-cheesesteak-slider
#
# --------
#
# https://fastfoodnutrition.org/subway/little-turkey-slider
#
# --------
#
# https://fastfoodnutrition.org/subway/meatball-marinara
#
# --------
#
# https://fastfoodnutrition.org/subway/oven-roasted-chicken
#
# --------
#
# https://fastfoodnutrition.org/subway/paneer-tikka-sandwich
#
# --------
#
# https://fastfoodnutrition.org/subway/roast-beef
#
# --------
#
# https://fastfoodnutrition.org/subway/rotisserie-style-chicken
#
# --------
#
# https://fastfoodnutrition.org/subway/southwest-chicken-club-sandwich
#
# --------
#
# https://fastfoodnutrition.org/subway/spicy-italian
#
# --------
#
# https://fastfoodnutrition.org/subway/steak-and-cheese
#
# --------
#
# https://fastfoodnutrition.org/subway/subway-club
#
# --------
#
# https://fastfoodnutrition.org/subway/subway-melt-includes-cheese
#
# --------
#
# https://fastfoodnutrition.org/subway/subway-seafood-sensation
#
# --------
#
# https://fastfoodnutrition.org/subway/sweet-onion-chicken-teriyaki
#
# --------
#
# https://fastfoodnutrition.org/subway/tuna
#
# --------
#
# https://fastfoodnutrition.org/subway/turkey-bacon-avocado
#
# --------
#
# https://fastfoodnutrition.org/subway/turkey-breast
#
# --------
#
# https://fastfoodnutrition.org/subway/turkey-breast-ham
#
# --------
#
# https://fastfoodnutrition.org/subway/turkey-italiano-melt-with-provolone
#
# --------
#
# https://fastfoodnutrition.org/subway/veggie-delite
#
# --------
#
# https://fastfoodnutrition.org/subway/veggie-patty
