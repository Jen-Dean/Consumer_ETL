# %%
import pandas as pd

# %%
jjs_table = pd.read_csv("Jimmy_Johns_Nutrition.csv")

# %%
jjs_table.head()
# Out:
#   sandwich_name                               sandwich_description  \
# 0        SLIM 1  Made with hand-sliced smoked ham and provolone...
# 1        SLIM 1  Made with hand-sliced smoked ham and provolone...
# 2        SLIM 1  Made with hand-sliced smoked ham and provolone...
# 3        SLIM 1  Made with hand-sliced smoked ham and provolone...
# 4        SLIM 2  Made with hand-sliced roast beef and served on...
#
#   restaurant_name          bread_type sandwich_length calories  \
# 0     Jimmy Johns              Unwich              na      190
# 1     Jimmy Johns        French Bread          8 Inch      120
# 2     Jimmy Johns  Thick-Sliced Wheat              na      560
# 3     Jimmy Johns        French Bread         16 Inch    1,160
# 4     Jimmy Johns              Unwich              na       90
#
#   calories_from_fat total_fat  saturated_fat  trans_fat  cholesterol sodium  \
# 0               100        11              6          0           50    900
# ...
