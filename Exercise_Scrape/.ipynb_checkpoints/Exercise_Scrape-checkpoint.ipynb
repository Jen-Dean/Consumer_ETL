# %%
from splinter import Browser
from bs4 import BeautifulSoup
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd

# %%
def init_browser():
    executable_path = {"executable_path": ChromeDriverManager().install()}
    return Browser("chrome", **executable_path, headless=False)

# %%
browser = init_browser()
listings = {}

url = "https://www.nutristrategy.com/caloriesburned.htm"
browser.visit(url)

html = browser.html
soup = BeautifulSoup(html, "html.parser")
# Out:
# [WDM] - Current google-chrome version is 86.0.4240
# [WDM] - Get LATEST driver version for 86.0.4240
# [WDM] - Driver [/Users/jenniferdean/.wdm/drivers/chromedriver/mac64/86.0.4240.22/chromedriver] found in cache

# %%
table = soup.find_all("table")[3]
table

browser.quit()

# %%
#NO HEADERS

exercises_list = []

for tr in table.find_all('tr')[1:]:
    try:
        exercise1 = tr.find_all('td')[0].get_text().split("\n")[0].strip()
        exercise2 = tr.find_all('td')[0].get_text().split("\n")[1].strip()
        calories_130lbs = tr.find_all('td')[1].get_text().strip()
        calories_155lbs = tr.find_all('td')[2].get_text().strip()
        calories_180lbs = tr.find_all('td')[3].get_text().strip()
        calories_205lbs = tr.find_all('td')[4].get_text().strip()
        final_string = f"{exercise1}{exercise2}"
        exercises_list.append(
        {"exercise (1 Hour)":final_string,
         "130 lbs": calories_130lbs,
         "155 lbs": calories_155lbs,
         "180 lbs": calories_180lbs,
         "205 lbs": calories_205lbs
        })
    except IndexError:
        pass
    
exercises_list
# Out:
# [{'exercise (1 Hour)': 'Cycling,mountain bike, bmx',
#   '130 lbs': '502',
#   '155 lbs': '598',
#   '180 lbs': '695',
#   '205 lbs': '791'},
#  {'exercise (1 Hour)': 'Cycling,<10 mph, leisure bicycling',
#   '130 lbs': '236',
#   '155 lbs': '281',
#   '180 lbs': '327',
#   '205 lbs': '372'},
#  {'exercise (1 Hour)': 'Cycling,>20 mph, racing',
#   '130 lbs': '944',
#   '155 lbs': '1126',
#   '180 lbs': '1308',
#   '205 lbs': '1489'},
#  {'exercise (1 Hour)': 'Cycling,10-11.9 mph, light',
#   '130 lbs': '354',
#   '155 lbs': '422',
#   '180 lbs': '490',
#   '205 lbs': '558'},
#  {'exercise (1 Hour)': 'Cycling,12-13.9 mph, moderate',
#   '130 lbs': '472',
#   '155 lbs': '563',
#   '180 lbs': '654',
#   '205 lbs': '745'},
#  {'exercise (1 Hour)': 'Cycling,14-15.9 mph, vigorous',
#   '130 lbs': '590',
#   '155 lbs': '704',
#   '180 lbs': '817',
#   '205 lbs': '931'},
#  {'exercise (1 Hour)': 'Cycling,16-19 mph, very fast, racing',
#   '130 lbs': '708',
#   '155 lbs': '844',
#   '180 lbs': '981',
#   '205 lbs': '1117'},
#  {'exercise (1 Hour)': 'Stationarycycling, very light',
#   '130 lbs': '177',
#   '155 lbs': '211',
#   '180 lbs': '245',
#   '205 lbs': '279'},
#  {'exercise (1 Hour)': 'Stationarycycling, light',
#   '130 lbs': '325',
#   '155 lbs': '387',
#   '180 lbs': '449',
#   '205 lbs': '512'},
#  {'exercise (1 Hour)': 'Stationarycycling, moderate',
#   '130 lbs': '413',
#   '155 lbs': '493',
#   '180 lbs': '572',
#   '205 lbs': '651'},
#  {'exercise (1 Hour)': 'Stationarycycling, vigorous',
#   '130 lbs': '620',
#   '155 lbs': '739',
#   '180 lbs': '858',
#   '205 lbs': '977'},
#  {'exercise (1 Hour)': 'Stationarycycling, very vigorous',
#   '130 lbs': '738',
#   '155 lbs': '880',
#   '180 lbs': '1022',
#   '205 lbs': '1163'},
#  {'exercise (1 Hour)': 'Calisthenics,vigorous, pushups, situps…',
#   '130 lbs': '472',
#   '155 lbs': '563',
#   '180 lbs': '654',
#   '205 lbs': '745'},
#  {'exercise (1 Hour)': 'Calisthenics,light',
#   '130 lbs': '207',
#   '155 lbs': '246',
#   '180 lbs': '286',
#   '205 lbs': '326'},
#  {'exercise (1 Hour)': 'Circuittraining, minimal rest',
#   '130 lbs': '472',
#   '155 lbs': '563',
#   '180 lbs': '654',
#   '205 lbs': '745'},
#  {'exercise (1 Hour)': 'Weightlifting, body building, vigorous',
#   '130 lbs': '354',
#   '155 lbs': '422',
#   '180 lbs': '490',
#   '205 lbs': '558'},
#  {'exercise (1 Hour)': 'Weightlifting, light workout',
#   '130 lbs': '177',
#   '155 lbs': '211',
#   '180 lbs': '245',
#   '205 lbs': '279'},
#  {'exercise (1 Hour)': 'Healthclub exercise',
#   '130 lbs': '325',
#   '155 lbs': '387',
#   '180 lbs': '449',
#   '205 lbs': '512'},
#  {'exercise (1 Hour)': 'Stairmachine',
#   '130 lbs': '531',
#   '155 lbs': '633',
#   '180 lbs': '735',
#   '205 lbs': '838'},
#  {'exercise (1 Hour)': 'Rowingmachine, light',
#   '130 lbs': '207',
#   '155 lbs': '246',
#   '180 lbs': '286',
#   '205 lbs': '326'},
#  {'exercise (1 Hour)': 'Rowingmachine, moderate',
#   '130 lbs': '413',
#   '155 lbs': '493',
#   '180 lbs': '572',
#   '205 lbs': '651'},
#  {'exercise (1 Hour)': 'Rowingmachine, vigorous',
#   '130 lbs': '502',
#   '155 lbs': '598',
#   '180 lbs': '695',
#   '205 lbs': '791'},
#  {'exercise (1 Hour)': 'Rowingmachine, very vigorous',
#   '130 lbs': '708',
#   '155 lbs': '844',
#   '180 lbs': '981',
#   '205 lbs': '1117'},
#  {'exercise (1 Hour)': 'Skimachine',
#   '130 lbs': '413',
#   '155 lbs': '493',
#   '180 lbs': '572',
#   '205 lbs': '651'},
#  {'exercise (1 Hour)': 'Aerobics,low impact',
#   '130 lbs': '295',
#   '155 lbs': '352',
#   '180 lbs': '409',
#   '205 lbs': '465'},
#  {'exercise (1 Hour)': 'Aerobics,high impact',
#   '130 lbs': '413',
#   '155 lbs': '493',
#   '180 lbs': '572',
#   '205 lbs': '651'},
#  {'exercise (1 Hour)': 'Aerobics,step aerobics',
#   '130 lbs': '502',
#   '155 lbs': '598',
#   '180 lbs': '695',
#   '205 lbs': '791'},
#  {'exercise (1 Hour)': 'Aerobics,general',
#   '130 lbs': '384',
#   '155 lbs': '457',
#   '180 lbs': '531',
#   '205 lbs': '605'},
#  {'exercise (1 Hour)': 'Stretching,hatha yoga',
#   '130 lbs': '236',
#   '155 lbs': '281',
#   '180 lbs': '327',
#   '205 lbs': '372'},
#  {'exercise (1 Hour)': 'Mildstretching',
#   '130 lbs': '148',
#   '155 lbs': '176',
#   '180 lbs': '204',
#   '205 lbs': '233'},
#  {'exercise (1 Hour)': 'Instructingaerobic class',
#   '130 lbs': '354',
#   '155 lbs': '422',
#   '180 lbs': '490',
#   '205 lbs': '558'},
#  {'exercise (1 Hour)': 'Wateraerobics',
#   '130 lbs': '236',
#   '155 lbs': '281',
#   '180 lbs': '327',
#   '205 lbs': '372'},
#  {'exercise (1 Hour)': 'Ballet,twist, jazz, tap',
#   '130 lbs': '266',
#   '155 lbs': '317',
#   '180 lbs': '368',
#   '205 lbs': '419'},
#  {'exercise (1 Hour)': 'Ballroomdancing, slow',
#   '130 lbs': '177',
#   '155 lbs': '211',
#   '180 lbs': '245',
#   '205 lbs': '279'},
#  {'exercise (1 Hour)': 'Ballroomdancing, fast',
#   '130 lbs': '325',
#   '155 lbs': '387',
#   '180 lbs': '449',
#   '205 lbs': '512'},
#  {'exercise (1 Hour)': 'Running,5 mph (12 minute mile)',
#   '130 lbs': '472',
#   '155 lbs': '563',
#   '180 lbs': '654',
#   '205 lbs': '745'},
#  {'exercise (1 Hour)': 'Running,5.2 mph (11.5 minute mile)',
#   '130 lbs': '531',
#   '155 lbs': '633',
#   '180 lbs': '735',
#   '205 lbs': '838'},
#  {'exercise (1 Hour)': 'Running,6 mph (10 min mile)',
#   '130 lbs': '590',
#   '155 lbs': '704',
#   '180 lbs': '817',
#   '205 lbs': '931'},
#  {'exercise (1 Hour)': 'Running,6.7 mph (9 min mile)',
#   '130 lbs': '649',
#   '155 lbs': '774',
#   '180 lbs': '899',
#   '205 lbs': '1024'},
#  {'exercise (1 Hour)': 'Running,7 mph (8.5 min mile)',
#   '130 lbs': '679',
#   '155 lbs': '809',
#   '180 lbs': '940',
#   '205 lbs': '1070'},
#  {'exercise (1 Hour)': 'Running,7.5mph (8 min mile)',
#   '130 lbs': '738',
#   '155 lbs': '880',
#   '180 lbs': '1022',
#   '205 lbs': '1163'},
#  {'exercise (1 Hour)': 'Running,8 mph (7.5 min mile)',
#   '130 lbs': '797',
#   '155 lbs': '950',
#   '180 lbs': '1103',
#   '205 lbs': '1256'},
#  {'exercise (1 Hour)': 'Running,8.6 mph (7 min mile)',
#   '130 lbs': '826',
#   '155 lbs': '985',
#   '180 lbs': '1144',
#   '205 lbs': '1303'},
#  {'exercise (1 Hour)': 'Running,9 mph (6.5 min mile)',
#   '130 lbs': '885',
#   '155 lbs': '1056',
#   '180 lbs': '1226',
#   '205 lbs': '1396'},
#  {'exercise (1 Hour)': 'Running,10 mph (6 min mile)',
#   '130 lbs': '944',
#   '155 lbs': '1126',
#   '180 lbs': '1308',
#   '205 lbs': '1489'},
#  {'exercise (1 Hour)': 'Running,10.9 mph (5.5 min mile)',
#   '130 lbs': '1062',
#   '155 lbs': '1267',
#   '180 lbs': '1471',
#   '205 lbs': '1675'},
#  {'exercise (1 Hour)': 'Running,cross country',
#   '130 lbs': '531',
#   '155 lbs': '633',
#   '180 lbs': '735',
#   '205 lbs': '838'},
#  {'exercise (1 Hour)': 'Running,general',
#   '130 lbs': '472',
#   '155 lbs': '563',
#   '180 lbs': '654',
#   '205 lbs': '745'},
#  {'exercise (1 Hour)': 'Running,on a track, team practice',
#   '130 lbs': '590',
#   '155 lbs': '704',
#   '180 lbs': '817',
#   '205 lbs': '931'},
#  {'exercise (1 Hour)': 'Running,stairs, up',
#   '130 lbs': '885',
#   '155 lbs': '1056',
#   '180 lbs': '1226',
#   '205 lbs': '1396'},
#  {'exercise (1 Hour)': 'Trackand field (shot, discus)',
#   '130 lbs': '236',
#   '155 lbs': '281',
#   '180 lbs': '327',
#   '205 lbs': '372'},
#  {'exercise (1 Hour)': 'Trackand field (high jump, pole vault)',
#   '130 lbs': '354',
#   '155 lbs': '422',
#   '180 lbs': '490',
#   '205 lbs': '558'},
#  {'exercise (1 Hour)': 'Trackand field (hurdles)',
#   '130 lbs': '590',
#   '155 lbs': '704',
#   '180 lbs': '817',
#   '205 lbs': '931'},
#  {'exercise (1 Hour)': 'Basketballgame, competitive',
#   '130 lbs': '472',
#   '155 lbs': '563',
#   '180 lbs': '654',
#   '205 lbs': '745'},
#  {'exercise (1 Hour)': 'Playingbasketball, non game',
#   '130 lbs': '354',
#   '155 lbs': '422',
#   '180 lbs': '490',
#   '205 lbs': '558'},
#  {'exercise (1 Hour)': 'Basketball,officiating',
#   '130 lbs': '413',
#   '155 lbs': '493',
#   '180 lbs': '572',
#   '205 lbs': '651'},
#  {'exercise (1 Hour)': 'Basketball,shooting baskets',
#   '130 lbs': '266',
#   '155 lbs': '317',
#   '180 lbs': '368',
#   '205 lbs': '419'},
#  {'exercise (1 Hour)': 'Basketball,wheelchair',
#   '130 lbs': '384',
#   '155 lbs': '457',
#   '180 lbs': '531',
#   '205 lbs': '605'},
#  {'exercise (1 Hour)': 'Running,training, pushing wheelchair',
#   '130 lbs': '472',
#   '155 lbs': '563',
#   '180 lbs': '654',
#   '205 lbs': '745'},
#  {'exercise (1 Hour)': 'Boxing,in ring',
#   '130 lbs': '708',
#   '155 lbs': '844',
#   '180 lbs': '981',
#   '205 lbs': '1117'},
#  {'exercise (1 Hour)': 'Boxing,punching bag',
#   '130 lbs': '354',
#   '155 lbs': '422',
#   '180 lbs': '490',
#   '205 lbs': '558'},
#  {'exercise (1 Hour)': 'Boxing,sparring',
#   '130 lbs': '531',
#   '155 lbs': '633',
#   '180 lbs': '735',
#   '205 lbs': '838'},
#  {'exercise (1 Hour)': 'Coaching:football, basketball, soccer…',
#   '130 lbs': '236',
#   '155 lbs': '281',
#   '180 lbs': '327',
#   '205 lbs': '372'},
#  {'exercise (1 Hour)': 'Cricket(batting, bowling)',
#   '130 lbs': '295',
#   '155 lbs': '352',
#   '180 lbs': '409',
#   '205 lbs': '465'},
#  {'exercise (1 Hour)': 'Darts(wall or lawn)',
#   '130 lbs': '148',
#   '155 lbs': '176',
#   '180 lbs': '204',
#   '205 lbs': '233'},
#  {'exercise (1 Hour)': 'Football,competitive',
#   '130 lbs': '531',
#   '155 lbs': '633',
#   '180 lbs': '735',
#   '205 lbs': '838'},
#  {'exercise (1 Hour)': 'Football,touch, flag, general',
#   '130 lbs': '472',
#   '155 lbs': '563',
#   '180 lbs': '654',
#   '205 lbs': '745'},
#  {'exercise (1 Hour)': 'Footballor baseball, playing catch',
#   '130 lbs': '148',
#   '155 lbs': '176',
#   '180 lbs': '204',
#   '205 lbs': '233'},
#  {'exercise (1 Hour)': 'Frisbeeplaying, general',
#   '130 lbs': '177',
#   '155 lbs': '211',
#   '180 lbs': '245',
#   '205 lbs': '279'},
#  {'exercise (1 Hour)': 'Frisbee,ultimate frisbee',
#   '130 lbs': '472',
#   '155 lbs': '563',
#   '180 lbs': '654',
#   '205 lbs': '745'},
#  {'exercise (1 Hour)': 'Golf,general',
#   '130 lbs': '266',
#   '155 lbs': '317',
#   '180 lbs': '368',
#   '205 lbs': '419'},
#  {'exercise (1 Hour)': 'Golf,walking and carrying clubs',
#   '130 lbs': '266',
#   '155 lbs': '317',
#   '180 lbs': '368',
#   '205 lbs': '419'},
#  {'exercise (1 Hour)': 'Golf,driving range',
#   '130 lbs': '177',
#   '155 lbs': '211',
#   '180 lbs': '245',
#   '205 lbs': '279'},
#  {'exercise (1 Hour)': 'Golf,miniature golf',
#   '130 lbs': '177',
#   '155 lbs': '211',
#   '180 lbs': '245',
#   '205 lbs': '279'},
#  {'exercise (1 Hour)': 'Golf,walking and pulling clubs',
#   '130 lbs': '254',
#   '155 lbs': '303',
#   '180 lbs': '351',
#   '205 lbs': '400'},
#  {'exercise (1 Hour)': 'Golf,using power cart',
#   '130 lbs': '207',
#   '155 lbs': '246',
#   '180 lbs': '286',
#   '205 lbs': '326'},
#  {'exercise (1 Hour)': 'Hackysack',
#   '130 lbs': '236',
#   '155 lbs': '281',
#   '180 lbs': '327',
#   '205 lbs': '372'},
#  {'exercise (1 Hour)': 'Handball,team',
#   '130 lbs': '472',
#   '155 lbs': '563',
#   '180 lbs': '654',
#   '205 lbs': '745'},
#  {'exercise (1 Hour)': 'Hockey,field hockey',
#   '130 lbs': '472',
#   '155 lbs': '563',
#   '180 lbs': '654',
#   '205 lbs': '745'},
#  {'exercise (1 Hour)': 'Hockey,ice hockey',
#   '130 lbs': '472',
#   '155 lbs': '563',
#   '180 lbs': '654',
#   '205 lbs': '745'},
#  {'exercise (1 Hour)': 'Ridinga horse, general',
#   '130 lbs': '236',
#   '155 lbs': '281',
#   '180 lbs': '327',
#   '205 lbs': '372'},
#  {'exercise (1 Hour)': 'Horesbackriding, saddling horse',
#   '130 lbs': '207',
#   '155 lbs': '246',
#   '180 lbs': '286',
#   '205 lbs': '326'},
#  {'exercise (1 Hour)': 'Horsebackriding, grooming horse',
#   '130 lbs': '207',
#   '155 lbs': '246',
#   '180 lbs': '286',
#   '205 lbs': '326'},
#  {'exercise (1 Hour)': 'Horsebackriding, trotting',
#   '130 lbs': '384',
#   '155 lbs': '457',
#   '180 lbs': '531',
#   '205 lbs': '605'},
#  {'exercise (1 Hour)': 'Horsebackriding, walking',
#   '130 lbs': '148',
#   '155 lbs': '176',
#   '180 lbs': '204',
#   '205 lbs': '233'},
#  {'exercise (1 Hour)': 'Horseracing, galloping',
#   '130 lbs': '472',
#   '155 lbs': '563',
#   '180 lbs': '654',
#   '205 lbs': '745'},
#  {'exercise (1 Hour)': 'Horsegrooming, moderate',
#   '130 lbs': '354',
#   '155 lbs': '422',
#   '180 lbs': '490',
#   '205 lbs': '558'},
#  {'exercise (1 Hour)': 'Horseshoepitching',
#   '130 lbs': '177',
#   '155 lbs': '211',
#   '180 lbs': '245',
#   '205 lbs': '279'},
#  {'exercise (1 Hour)': 'Jaialai',
#   '130 lbs': '708',
#   '155 lbs': '844',
#   '180 lbs': '981',
#   '205 lbs': '1117'},
#  {'exercise (1 Hour)': 'Martialarts, judo, karate, jujitsu',
#   '130 lbs': '590',
#   '155 lbs': '704',
#   '180 lbs': '817',
#   '205 lbs': '931'},
#  {'exercise (1 Hour)': 'Martialarts, kick boxing',
#   '130 lbs': '590',
#   '155 lbs': '704',
#   '180 lbs': '817',
#   '205 lbs': '931'},
#  {'exercise (1 Hour)': 'Martialarts, tae kwan do',
#   '130 lbs': '590',
#   '155 lbs': '704',
#   '180 lbs': '817',
#   '205 lbs': '931'},
#  {'exercise (1 Hour)': 'Kravmaga training',
#   '130 lbs': '590',
#   '155 lbs': '704',
#   '180 lbs': '817',
#   '205 lbs': '931'},
#  {'exercise (1 Hour)': 'Playingpaddleball',
#   '130 lbs': '354',
#   '155 lbs': '422',
#   '180 lbs': '490',
#   '205 lbs': '558'},
#  {'exercise (1 Hour)': 'Paddleball,competitive',
#   '130 lbs': '590',
#   '155 lbs': '704',
#   '180 lbs': '817',
#   '205 lbs': '931'},
#  {'exercise (1 Hour)': 'Racquetball,competitive',
#   '130 lbs': '590',
#   '155 lbs': '704',
#   '180 lbs': '817',
#   '205 lbs': '931'},
#  {'exercise (1 Hour)': 'Playingracquetball',
#   '130 lbs': '413',
#   '155 lbs': '493',
#   '180 lbs': '572',
#   '205 lbs': '651'},
#  {'exercise (1 Hour)': 'Rockclimbing, ascending rock',
#   '130 lbs': '649',
#   '155 lbs': '774',
#   '180 lbs': '899',
#   '205 lbs': '1024'},
#  {'exercise (1 Hour)': 'Rockclimbing, rappelling',
#   '130 lbs': '472',
#   '155 lbs': '563',
#   '180 lbs': '654',
#   '205 lbs': '745'},
#  {'exercise (1 Hour)': 'Jumpingrope, fast',
#   '130 lbs': '708',
#   '155 lbs': '844',
#   '180 lbs': '981',
#   '205 lbs': '1117'},
#  {'exercise (1 Hour)': 'Jumpingrope, moderate',
#   '130 lbs': '590',
#   '155 lbs': '704',
#   '180 lbs': '817',
#   '205 lbs': '931'},
#  {'exercise (1 Hour)': 'Jumpingrope, slow',
#   '130 lbs': '472',
#   '155 lbs': '563',
#   '180 lbs': '654',
#   '205 lbs': '745'},
#  {'exercise (1 Hour)': 'Shuffleboard,lawn bowling',
#   '130 lbs': '177',
#   '155 lbs': '211',
#   '180 lbs': '245',
#   '205 lbs': '279'},
#  {'exercise (1 Hour)': 'Rollerskating',
#   '130 lbs': '413',
#   '155 lbs': '493',
#   '180 lbs': '572',
#   '205 lbs': '651'},
#  {'exercise (1 Hour)': 'Rollerblading, in-line skating',
#   '130 lbs': '708',
#   '155 lbs': '844',
#   '180 lbs': '981',
#   '205 lbs': '1117'},
#  {'exercise (1 Hour)': 'Skydiving',
#   '130 lbs': '177',
#   '155 lbs': '211',
#   '180 lbs': '245',
#   '205 lbs': '279'},
#  {'exercise (1 Hour)': 'Soccer,competitive',
#   '130 lbs': '590',
#   '155 lbs': '704',
#   '180 lbs': '817',
#   '205 lbs': '931'},
#  {'exercise (1 Hour)': 'Playingsoccer',
#   '130 lbs': '413',
#   '155 lbs': '493',
#   '180 lbs': '572',
#   '205 lbs': '651'},
#  {'exercise (1 Hour)': 'Softballor baseball',
#   '130 lbs': '295',
#   '155 lbs': '352',
#   '180 lbs': '409',
#   '205 lbs': '465'},
#  {'exercise (1 Hour)': 'Softball,officiating',
#   '130 lbs': '236',
#   '155 lbs': '281',
#   '180 lbs': '327',
#   '205 lbs': '372'},
#  {'exercise (1 Hour)': 'Softball,pitching',
#   '130 lbs': '354',
#   '155 lbs': '422',
#   '180 lbs': '490',
#   '205 lbs': '558'},
#  {'exercise (1 Hour)': 'Tabletennis, ping pong',
#   '130 lbs': '236',
#   '155 lbs': '281',
#   '180 lbs': '327',
#   '205 lbs': '372'},
#  {'exercise (1 Hour)': 'Taichi',
#   '130 lbs': '236',
#   '155 lbs': '281',
#   '180 lbs': '327',
#   '205 lbs': '372'},
#  {'exercise (1 Hour)': 'Playingtennis',
#   '130 lbs': '413',
#   '155 lbs': '493',
#   '180 lbs': '572',
#   '205 lbs': '651'},
#  {'exercise (1 Hour)': 'Tennis,doubles',
#   '130 lbs': '354',
#   '155 lbs': '422',
#   '180 lbs': '490',
#   '205 lbs': '558'},
#  {'exercise (1 Hour)': 'Tennis,singles',
#   '130 lbs': '472',
#   '155 lbs': '563',
#   '180 lbs': '654',
#   '205 lbs': '745'},
#  {'exercise (1 Hour)': 'Volleyball,competitive',
#   '130 lbs': '472',
#   '155 lbs': '563',
#   '180 lbs': '654',
#   '205 lbs': '745'},
#  {'exercise (1 Hour)': 'Playingvolleyball',
#   '130 lbs': '177',
#   '155 lbs': '211',
#   '180 lbs': '245',
#   '205 lbs': '279'},
#  {'exercise (1 Hour)': 'Volleyball,beach',
#   '130 lbs': '472',
#   '155 lbs': '563',
#   '180 lbs': '654',
#   '205 lbs': '745'},
#  {'exercise (1 Hour)': 'Backpacking,Hiking with pack',
#   '130 lbs': '413',
#   '155 lbs': '493',
#   '180 lbs': '572',
#   '205 lbs': '651'},
#  {'exercise (1 Hour)': 'Carryinginfant, level ground',
#   '130 lbs': '207',
#   '155 lbs': '246',
#   '180 lbs': '286',
#   '205 lbs': '326'},
#  {'exercise (1 Hour)': 'Carryinginfant, upstairs',
#   '130 lbs': '295',
#   '155 lbs': '352',
#   '180 lbs': '409',
#   '205 lbs': '465'},
#  {'exercise (1 Hour)': 'Carrying16 to 24 lbs, upstairs',
#   '130 lbs': '354',
#   '155 lbs': '422',
#   '180 lbs': '490',
#   '205 lbs': '558'},
#  {'exercise (1 Hour)': 'Carrying25 to 49 lbs, upstairs',
#   '130 lbs': '472',
#   '155 lbs': '563',
#   '180 lbs': '654',
#   '205 lbs': '745'},
#  {'exercise (1 Hour)': 'Standing,playing with children, light',
#   '130 lbs': '165',
#   '155 lbs': '197',
#   '180 lbs': '229',
#   '205 lbs': '261'},
#  {'exercise (1 Hour)': 'Walk/run,playing with children, moderate',
#   '130 lbs': '236',
#   '155 lbs': '281',
#   '180 lbs': '327',
#   '205 lbs': '372'},
#  {'exercise (1 Hour)': 'Walk/run,playing with children, vigorous',
#   '130 lbs': '295',
#   '155 lbs': '352',
#   '180 lbs': '409',
#   '205 lbs': '465'},
#  {'exercise (1 Hour)': 'Carryingsmall children',
#   '130 lbs': '177',
#   '155 lbs': '211',
#   '180 lbs': '245',
#   '205 lbs': '279'},
#  {'exercise (1 Hour)': 'Loading,unloading car',
#   '130 lbs': '177',
#   '155 lbs': '211',
#   '180 lbs': '245',
#   '205 lbs': '279'},
#  {'exercise (1 Hour)': 'Climbinghills, carrying up to 9 lbs',
#   '130 lbs': '413',
#   '155 lbs': '493',
#   '180 lbs': '572',
#   '205 lbs': '651'},
#  {'exercise (1 Hour)': 'Climbinghills, carrying 10 to 20 lb',
#   '130 lbs': '443',
#   '155 lbs': '528',
#   '180 lbs': '613',
#   '205 lbs': '698'},
#  {'exercise (1 Hour)': 'Climbinghills, carrying 21 to 42 lb',
#   '130 lbs': '472',
#   '155 lbs': '563',
#   '180 lbs': '654',
#   '205 lbs': '745'},
#  {'exercise (1 Hour)': 'Climbinghills, carrying over 42 lb',
#   '130 lbs': '531',
#   '155 lbs': '633',
#   '180 lbs': '735',
#   '205 lbs': '838'},
#  {'exercise (1 Hour)': 'Walkingdownstairs',
#   '130 lbs': '177',
#   '155 lbs': '211',
#   '180 lbs': '245',
#   '205 lbs': '279'},
#  {'exercise (1 Hour)': 'Hiking,cross country',
#   '130 lbs': '354',
#   '155 lbs': '422',
#   '180 lbs': '490',
#   '205 lbs': '558'},
#  {'exercise (1 Hour)': 'Birdwatching',
#   '130 lbs': '148',
#   '155 lbs': '176',
#   '180 lbs': '204',
#   '205 lbs': '233'},
#  {'exercise (1 Hour)': 'Marching,rapidly, military',
#   '130 lbs': '384',
#   '155 lbs': '457',
#   '180 lbs': '531',
#   '205 lbs': '605'},
#  {'exercise (1 Hour)': "Children'sgames, hopscotch, dodgeball",
#   '130 lbs': '295',
#   '155 lbs': '352',
#   '180 lbs': '409',
#   '205 lbs': '465'},
#  {'exercise (1 Hour)': 'Pushingstroller or walking with children',
#   '130 lbs': '148',
#   '155 lbs': '176',
#   '180 lbs': '204',
#   '205 lbs': '233'},
#  {'exercise (1 Hour)': 'Pushinga wheelchair',
#   '130 lbs': '236',
#   '155 lbs': '281',
#   '180 lbs': '327',
#   '205 lbs': '372'},
#  {'exercise (1 Hour)': 'Racewalking',
#   '130 lbs': '384',
#   '155 lbs': '457',
#   '180 lbs': '531',
#   '205 lbs': '605'},
#  {'exercise (1 Hour)': 'Rockclimbing, mountain climbing',
#   '130 lbs': '472',
#   '155 lbs': '563',
#   '180 lbs': '654',
#   '205 lbs': '745'},
#  {'exercise (1 Hour)': 'Walkingusing crutches',
#   '130 lbs': '295',
#   '155 lbs': '352',
#   '180 lbs': '409',
#   '205 lbs': '465'},
#  {'exercise (1 Hour)': 'Walkingthe dog',
#   '130 lbs': '177',
#   '155 lbs': '211',
#   '180 lbs': '245',
#   '205 lbs': '279'},
#  {'exercise (1 Hour)': 'Walking,under 2.0 mph, very slow',
#   '130 lbs': '118',
#   '155 lbs': '141',
#   '180 lbs': '163',
#   '205 lbs': '186'},
#  {'exercise (1 Hour)': 'Walking2.0 mph, slow',
#   '130 lbs': '148',
#   '155 lbs': '176',
#   '180 lbs': '204',
#   '205 lbs': '233'},
#  {'exercise (1 Hour)': 'Walking2.5 mph',
#   '130 lbs': '177',
#   '155 lbs': '211',
#   '180 lbs': '245',
#   '205 lbs': '279'},
#  {'exercise (1 Hour)': 'Walking3.0 mph, moderate',
#   '130 lbs': '195',
#   '155 lbs': '232',
#   '180 lbs': '270',
#   '205 lbs': '307'},
#  {'exercise (1 Hour)': 'Walking3.5 mph, brisk pace',
#   '130 lbs': '224',
#   '155 lbs': '267',
#   '180 lbs': '311',
#   '205 lbs': '354'},
#  {'exercise (1 Hour)': 'Walking3.5 mph, uphill',
#   '130 lbs': '354',
#   '155 lbs': '422',
#   '180 lbs': '490',
#   '205 lbs': '558'},
#  {'exercise (1 Hour)': 'Walking4.0 mph, very brisk',
#   '130 lbs': '295',
#   '155 lbs': '352',
#   '180 lbs': '409',
#   '205 lbs': '465'},
#  {'exercise (1 Hour)': 'Walking4.5 mph',
#   '130 lbs': '372',
#   '155 lbs': '443',
#   '180 lbs': '515',
#   '205 lbs': '586'},
#  {'exercise (1 Hour)': 'Walking5.0 mph',
#   '130 lbs': '472',
#   '155 lbs': '563',
#   '180 lbs': '654',
#   '205 lbs': '745'},
#  {'exercise (1 Hour)': 'Boating,power, speed boat',
#   '130 lbs': '148',
#   '155 lbs': '176',
#   '180 lbs': '204',
#   '205 lbs': '233'},
#  {'exercise (1 Hour)': 'Canoeing,camping trip',
#   '130 lbs': '236',
#   '155 lbs': '281',
#   '180 lbs': '327',
#   '205 lbs': '372'},
#  {'exercise (1 Hour)': 'Canoeing,rowing, light',
#   '130 lbs': '177',
#   '155 lbs': '211',
#   '180 lbs': '245',
#   '205 lbs': '279'},
#  {'exercise (1 Hour)': 'Canoeing,rowing, moderate',
#   '130 lbs': '413',
#   '155 lbs': '493',
#   '180 lbs': '572',
#   '205 lbs': '651'},
#  {'exercise (1 Hour)': 'Canoeing,rowing, vigorous',
#   '130 lbs': '708',
#   '155 lbs': '844',
#   '180 lbs': '981',
#   '205 lbs': '1117'},
#  {'exercise (1 Hour)': 'Crew,sculling, rowing, competition',
#   '130 lbs': '708',
#   '155 lbs': '844',
#   '180 lbs': '981',
#   '205 lbs': '1117'},
#  {'exercise (1 Hour)': 'Paddleboat',
#   '130 lbs': '236',
#   '155 lbs': '281',
#   '180 lbs': '327',
#   '205 lbs': '372'},
#  {'exercise (1 Hour)': 'Windsurfing,sailing',
#   '130 lbs': '177',
#   '155 lbs': '211',
#   '180 lbs': '245',
#   '205 lbs': '279'},
#  {'exercise (1 Hour)': 'Sailing,competition',
#   '130 lbs': '295',
#   '155 lbs': '352',
#   '180 lbs': '409',
#   '205 lbs': '465'},
#  {'exercise (1 Hour)': 'Sailing,yachting, ocean sailing',
#   '130 lbs': '177',
#   '155 lbs': '211',
#   '180 lbs': '245',
#   '205 lbs': '279'},
#  {'exercise (1 Hour)': 'Skiing,water skiing',
#   '130 lbs': '354',
#   '155 lbs': '422',
#   '180 lbs': '490',
#   '205 lbs': '558'},
#  {'exercise (1 Hour)': 'Skimobiling',
#   '130 lbs': '413',
#   '155 lbs': '493',
#   '180 lbs': '572',
#   '205 lbs': '651'},
#  {'exercise (1 Hour)': 'Skindiving, fast',
#   '130 lbs': '944',
#   '155 lbs': '1126',
#   '180 lbs': '1308',
#   '205 lbs': '1489'},
#  {'exercise (1 Hour)': 'Skindiving, moderate',
#   '130 lbs': '738',
#   '155 lbs': '880',
#   '180 lbs': '1022',
#   '205 lbs': '1163'},
#  {'exercise (1 Hour)': 'Skindiving, scuba diving',
#   '130 lbs': '413',
#   '155 lbs': '493',
#   '180 lbs': '572',
#   '205 lbs': '651'},
#  {'exercise (1 Hour)': 'Surfing,body surfing or board surfing',
#   '130 lbs': '177',
#   '155 lbs': '211',
#   '180 lbs': '245',
#   '205 lbs': '279'},
#  {'exercise (1 Hour)': 'Whitewaterrafting, kayaking, canoeing',
#   '130 lbs': '295',
#   '155 lbs': '352',
#   '180 lbs': '409',
#   '205 lbs': '465'},
#  {'exercise (1 Hour)': 'Swimminglaps, freestyle, fast',
#   '130 lbs': '590',
#   '155 lbs': '704',
#   '180 lbs': '817',
#   '205 lbs': '931'},
#  {'exercise (1 Hour)': 'Swimminglaps, freestyle, slow',
#   '130 lbs': '413',
#   '155 lbs': '493',
#   '180 lbs': '572',
#   '205 lbs': '651'},
#  {'exercise (1 Hour)': 'Swimmingbackstroke',
#   '130 lbs': '413',
#   '155 lbs': '493',
#   '180 lbs': '572',
#   '205 lbs': '651'},
#  {'exercise (1 Hour)': 'Swimmingbreaststroke',
#   '130 lbs': '590',
#   '155 lbs': '704',
#   '180 lbs': '817',
#   '205 lbs': '931'},
#  {'exercise (1 Hour)': 'Swimmingbutterfly',
#   '130 lbs': '649',
#   '155 lbs': '774',
#   '180 lbs': '899',
#   '205 lbs': '1024'},
#  {'exercise (1 Hour)': 'Swimmingleisurely, not laps',
#   '130 lbs': '354',
#   '155 lbs': '422',
#   '180 lbs': '490',
#   '205 lbs': '558'},
#  {'exercise (1 Hour)': 'Swimmingsidestroke',
#   '130 lbs': '472',
#   '155 lbs': '563',
#   '180 lbs': '654',
#   '205 lbs': '745'},
#  {'exercise (1 Hour)': 'Swimmingsynchronized',
#   '130 lbs': '472',
#   '155 lbs': '563',
#   '180 lbs': '654',
#   '205 lbs': '745'},
#  {'exercise (1 Hour)': 'Swimming,treading water, fast, vigorous',
#   '130 lbs': '590',
#   '155 lbs': '704',
#   '180 lbs': '817',
#   '205 lbs': '931'},
#  {'exercise (1 Hour)': 'Swimming,treading water, moderate',
#   '130 lbs': '236',
#   '155 lbs': '281',
#   '180 lbs': '327',
#   '205 lbs': '372'},
#  {'exercise (1 Hour)': 'Wateraerobics, water calisthenics',
#   '130 lbs': '236',
#   '155 lbs': '281',
#   '180 lbs': '327',
#   '205 lbs': '372'},
#  {'exercise (1 Hour)': 'Waterpolo',
#   '130 lbs': '590',
#   '155 lbs': '704',
#   '180 lbs': '817',
#   '205 lbs': '931'},
#  {'exercise (1 Hour)': 'Watervolleyball',
#   '130 lbs': '177',
#   '155 lbs': '211',
#   '180 lbs': '245',
#   '205 lbs': '279'},
#  {'exercise (1 Hour)': 'Waterjogging',
#   '130 lbs': '472',
#   '155 lbs': '563',
#   '180 lbs': '654',
#   '205 lbs': '745'},
#  {'exercise (1 Hour)': 'Diving,springboard or platform',
#   '130 lbs': '177',
#   '155 lbs': '211',
#   '180 lbs': '245',
#   '205 lbs': '279'},
#  {'exercise (1 Hour)': 'Iceskating, < 9 mph',
#   '130 lbs': '325',
#   '155 lbs': '387',
#   '180 lbs': '449',
#   '205 lbs': '512'},
#  {'exercise (1 Hour)': 'Iceskating, average speed',
#   '130 lbs': '413',
#   '155 lbs': '493',
#   '180 lbs': '572',
#   '205 lbs': '651'},
#  {'exercise (1 Hour)': 'Iceskating, rapidly',
#   '130 lbs': '531',
#   '155 lbs': '633',
#   '180 lbs': '735',
#   '205 lbs': '838'},
#  {'exercise (1 Hour)': 'Speedskating, ice, competitive',
#   '130 lbs': '885',
#   '155 lbs': '1056',
#   '180 lbs': '1226',
#   '205 lbs': '1396'},
#  {'exercise (1 Hour)': 'Crosscountry snow skiing, slow',
#   '130 lbs': '413',
#   '155 lbs': '493',
#   '180 lbs': '572',
#   '205 lbs': '651'},
#  {'exercise (1 Hour)': 'Crosscountry skiing, moderate',
#   '130 lbs': '472',
#   '155 lbs': '563',
#   '180 lbs': '654',
#   '205 lbs': '745'},
#  {'exercise (1 Hour)': 'Crosscountry skiing, vigorous',
#   '130 lbs': '531',
#   '155 lbs': '633',
#   '180 lbs': '735',
#   '205 lbs': '838'},
#  {'exercise (1 Hour)': 'Crosscountry skiing, racing',
#   '130 lbs': '826',
#   '155 lbs': '985',
#   '180 lbs': '1144',
#   '205 lbs': '1303'},
#  {'exercise (1 Hour)': 'Crosscountry skiing, uphill',
#   '130 lbs': '974',
#   '155 lbs': '1161',
#   '180 lbs': '1348',
#   '205 lbs': '1536'},
#  {'exercise (1 Hour)': 'Snowskiing, downhill skiing, light',
#   '130 lbs': '295',
#   '155 lbs': '352',
#   '180 lbs': '409',
#   '205 lbs': '465'},
#  {'exercise (1 Hour)': 'Downhillsnow skiing, moderate',
#   '130 lbs': '354',
#   '155 lbs': '422',
#   '180 lbs': '490',
#   '205 lbs': '558'},
#  {'exercise (1 Hour)': 'Downhillsnow skiing, racing',
#   '130 lbs': '472',
#   '155 lbs': '563',
#   '180 lbs': '654',
#   '205 lbs': '745'},
#  {'exercise (1 Hour)': 'Sledding,tobagganing, luge',
#   '130 lbs': '413',
#   '155 lbs': '493',
#   '180 lbs': '572',
#   '205 lbs': '651'},
#  {'exercise (1 Hour)': 'Snowshoeing',
#   '130 lbs': '472',
#   '155 lbs': '563',
#   '180 lbs': '654',
#   '205 lbs': '745'},
#  {'exercise (1 Hour)': 'Generalhousework',
#   '130 lbs': '207',
#   '155 lbs': '246',
#   '180 lbs': '286',
#   '205 lbs': '326'},
#  {'exercise (1 Hour)': 'Cleaninggutters',
#   '130 lbs': '295',
#   '155 lbs': '352',
#   '180 lbs': '409',
#   '205 lbs': '465'},
#  {'exercise (1 Hour)': 'Sit,playing with animals',
#   '130 lbs': '148',
#   '155 lbs': '176',
#   '180 lbs': '204',
#   '205 lbs': '233'},
#  {'exercise (1 Hour)': 'Walk/ run, playing with animals',
#   '130 lbs': '236',
#   '155 lbs': '281',
#   '180 lbs': '327',
#   '205 lbs': '372'},
#  {'exercise (1 Hour)': 'Bathingdog',
#   '130 lbs': '207',
#   '155 lbs': '246',
#   '180 lbs': '286',
#   '205 lbs': '326'},
#  {'exercise (1 Hour)': 'Mowinglawn, walk, power mower',
#   '130 lbs': '325',
#   '155 lbs': '387',
#   '180 lbs': '449',
#   '205 lbs': '512'},
#  {'exercise (1 Hour)': 'Mowinglawn, riding mower',
#   '130 lbs': '148',
#   '155 lbs': '176',
#   '180 lbs': '204',
#   '205 lbs': '233'},
#  {'exercise (1 Hour)': 'Walking,snow blower',
#   '130 lbs': '207',
#   '155 lbs': '246',
#   '180 lbs': '286',
#   '205 lbs': '326'},
#  {'exercise (1 Hour)': 'Riding,snow blower',
#   '130 lbs': '177',
#   '155 lbs': '211',
#   '180 lbs': '245',
#   '205 lbs': '279'},
#  {'exercise (1 Hour)': 'Shovelingsnow by hand',
#   '130 lbs': '354',
#   '155 lbs': '422',
#   '180 lbs': '490',
#   '205 lbs': '558'},
#  {'exercise (1 Hour)': 'Rakinglawn',
#   '130 lbs': '254',
#   '155 lbs': '303',
#   '180 lbs': '351',
#   '205 lbs': '400'},
#  {'exercise (1 Hour)': 'Gardening,general',
#   '130 lbs': '236',
#   '155 lbs': '281',
#   '180 lbs': '327',
#   '205 lbs': '372'},
#  {'exercise (1 Hour)': 'Bagginggrass, leaves',
#   '130 lbs': '236',
#   '155 lbs': '281',
#   '180 lbs': '327',
#   '205 lbs': '372'},
#  {'exercise (1 Hour)': 'Wateringlawn or garden',
#   '130 lbs': '89',
#   '155 lbs': '106',
#   '180 lbs': '123',
#   '205 lbs': '140'},
#  {'exercise (1 Hour)': 'Weeding,cultivating garden',
#   '130 lbs': '266',
#   '155 lbs': '317',
#   '180 lbs': '368',
#   '205 lbs': '419'},
#  {'exercise (1 Hour)': 'Carpentry,general',
#   '130 lbs': '207',
#   '155 lbs': '246',
#   '180 lbs': '286',
#   '205 lbs': '326'},
#  {'exercise (1 Hour)': 'Carryingheavy loads',
#   '130 lbs': '472',
#   '155 lbs': '563',
#   '180 lbs': '654',
#   '205 lbs': '745'},
#  {'exercise (1 Hour)': 'Carryingmoderate loads upstairs',
#   '130 lbs': '472',
#   '155 lbs': '563',
#   '180 lbs': '654',
#   '205 lbs': '745'},
#  {'exercise (1 Hour)': 'Generalcleaning',
#   '130 lbs': '207',
#   '155 lbs': '246',
#   '180 lbs': '286',
#   '205 lbs': '326'},
#  {'exercise (1 Hour)': 'Cleaning,dusting',
#   '130 lbs': '148',
#   '155 lbs': '176',
#   '180 lbs': '204',
#   '205 lbs': '233'},
#  {'exercise (1 Hour)': 'Takingout trash',
#   '130 lbs': '177',
#   '155 lbs': '211',
#   '180 lbs': '245',
#   '205 lbs': '279'},
#  {'exercise (1 Hour)': 'Walking,pushing a wheelchair',
#   '130 lbs': '236',
#   '155 lbs': '281',
#   '180 lbs': '327',
#   '205 lbs': '372'},
#  {'exercise (1 Hour)': 'Teachphysical education,exercise class',
#   '130 lbs': '236',
#   '155 lbs': '281',
#   '180 lbs': '327',
#   '205 lbs': '372'},
#  {'exercise (1 Hour)': 'Teachexercise classes (& participate)',
#   '130 lbs': '384',
#   '155 lbs': '457',
#   '180 lbs': '531',
#   '205 lbs': '605'}]

# %%
exercises_df = pd.DataFrame(exercises_list)
exercises_df
# Out:
#                           exercise (1 Hour) 130 lbs 155 lbs 180 lbs 205 lbs
# 0                Cycling,mountain bike, bmx     502     598     695     791
# 1        Cycling,<10 mph, leisure bicycling     236     281     327     372
# 2                   Cycling,>20 mph, racing     944    1126    1308    1489
# 3                Cycling,10-11.9 mph, light     354     422     490     558
# 4             Cycling,12-13.9 mph, moderate     472     563     654     745
# ..                                      ...     ...     ...     ...     ...
# 218                        Cleaning,dusting     148     176     204     233
# 219                         Takingout trash     177     211     245     279
# 220            Walking,pushing a wheelchair     236     281     327     372
# 221  Teachphysical education,exercise class     236     281     327     372
# 222   Teachexercise classes (& participate)     384     457     531     605
#
# [223 rows x 5 columns]

# %%
exercises_df["130 lbs"] = pd.to_numeric(exercises_df["130 lbs"])
exercises_df["155 lbs"] = pd.to_numeric(exercises_df["155 lbs"])
exercises_df["180 lbs"] = pd.to_numeric(exercises_df["180 lbs"])
exercises_df["205 lbs"] = pd.to_numeric(exercises_df["205 lbs"])


exercises_df
# Out:
#                           exercise (1 Hour)  130 lbs  155 lbs  180 lbs  \
# 0                Cycling,mountain bike, bmx      502      598      695
# 1        Cycling,<10 mph, leisure bicycling      236      281      327
# 2                   Cycling,>20 mph, racing      944     1126     1308
# 3                Cycling,10-11.9 mph, light      354      422      490
# 4             Cycling,12-13.9 mph, moderate      472      563      654
# ..                                      ...      ...      ...      ...
# 218                        Cleaning,dusting      148      176      204
# 219                         Takingout trash      177      211      245
# 220            Walking,pushing a wheelchair      236      281      327
# 221  Teachphysical education,exercise class      236      281      327
# 222   Teachexercise classes (& participate)      384      457      531
#
#      205 lbs
# 0        791
# 1        372
# 2       1489
# 3        558
# 4        745
# ..       ...
# 218      233
# 219      279
# 220      372
# 221      372
# 222      605
#
# [223 rows x 5 columns]

# %%
exercises_df.to_csv("exercise.csv", index=False)

# %%
per_min_exercises_df = exercises_df

# %%
per_min_exercises_df["130 lbs"] /= 60
per_min_exercises_df["155 lbs"] /= 60 
per_min_exercises_df["180 lbs"] /= 60 
per_min_exercises_df["205 lbs"] /= 60

# %%
per_min_exercises_df = per_min_exercises_df.round(1)
per_min_exercises_df = per_min_exercises_df.rename(columns={"exercise (1 Hour)":"exercise",
                                                            "130 lbs": "130_lbs", 
                                                            "155 lbs": "155_lbs", 
                                                            "180 lbs":"180_lbs", 
                                                            "205 lbs":"205_lbs"})
per_min_exercises_df
# Out:
#     exercise_id                                exercise  130_lbs  155_lbs  \
# 0                            Cycling,mountain bike, bmx      8.4     10.0
# 1                    Cycling,<10 mph, leisure bicycling      3.9      4.7
# 2                               Cycling,>20 mph, racing     15.7     18.8
# 3                            Cycling,10-11.9 mph, light      5.9      7.0
# 4                         Cycling,12-13.9 mph, moderate      7.9      9.4
# ..          ...                                     ...      ...      ...
# 218                                    Cleaning,dusting      2.5      2.9
# 219                                     Takingout trash      3.0      3.5
# 220                        Walking,pushing a wheelchair      3.9      4.7
# 221              Teachphysical education,exercise class      3.9      4.7
# 222               Teachexercise classes (& participate)      6.4      7.6
#
#      180_lbs  205_lbs
# 0       11.6     13.2
# 1        5.4      6.2
# 2       21.8     24.8
# 3        8.2      9.3
# 4       10.9     12.4
# ..       ...      ...
# 218      3.4      3.9
# 219      4.1      4.6
# 220      5.4      6.2
# 221      5.4      6.2
# 222      8.8     10.1
#
# [223 rows x 6 columns]

# %%
per_min_exercises_df.insert(0, "exercise_id", "", True)
per_min_exercises_df
# Out:
#     exercise_id                                exercise  130 lbs  155 lbs  \
# 0                            Cycling,mountain bike, bmx      8.4     10.0
# 1                    Cycling,<10 mph, leisure bicycling      3.9      4.7
# 2                               Cycling,>20 mph, racing     15.7     18.8
# 3                            Cycling,10-11.9 mph, light      5.9      7.0
# 4                         Cycling,12-13.9 mph, moderate      7.9      9.4
# ..          ...                                     ...      ...      ...
# 218                                    Cleaning,dusting      2.5      2.9
# 219                                     Takingout trash      3.0      3.5
# 220                        Walking,pushing a wheelchair      3.9      4.7
# 221              Teachphysical education,exercise class      3.9      4.7
# 222               Teachexercise classes (& participate)      6.4      7.6
#
#      180 lbs  205 lbs
# 0       11.6     13.2
# 1        5.4      6.2
# 2       21.8     24.8
# 3        8.2      9.3
# 4       10.9     12.4
# ..       ...      ...
# 218      3.4      3.9
# 219      4.1      4.6
# 220      5.4      6.2
# 221      5.4      6.2
# 222      8.8     10.1
#
# [223 rows x 6 columns]

# %%
per_min_exercises_df.to_csv("per_min_exercise.csv", index=False)
